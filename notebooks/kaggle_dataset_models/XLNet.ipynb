# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip3 install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.28.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)

# %%
import torch

# Set the device to use
device = torch.device('cuda')

# Enable GPU memory growth
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.deterministic = True
torch.cuda.empty_cache()

# %% [markdown]
# ## Data Pre-processing

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Read dataset file

# %%
import pandas as pd
import numpy as np

train_filename = "/content/drive/MyDrive/NLP Project/Datasets/Kaggle/trainkaggle.csv"
test_filename = "/content/drive/MyDrive/NLP Project/Datasets/Kaggle/testkaggle.csv"

df_train = pd.read_csv(train_filename)
df_test = pd.read_csv(test_filename)

# %%
df_train.columns.values.tolist()
# Out:
# ['Unnamed: 0', 'tweetText', 'label']

# %%
df_train = df_train.drop('Unnamed: 0', axis=1)

# %%
df_test = df_test.drop('Unnamed: 0', axis=1)

# %%
df_train = df_train.rename(columns={'tweetText': 'text'})
df_test = df_test.rename(columns={'tweetText': 'text'})

# %%
df_train.head()
# Out:
#                                                 text label
# 0  anyone actually believe possible Barack Hussei...  fake
# 1  Two law enforcement officials Utah resort area...  fake
# 2  8 brutal years race-baiting, endless stories v...  fake
# 3  BEIRUT (Reuters) Iranian military vessel confr...  real
# 4  Elizabeth Warren went attack Donald Trump Sund...  fake

# %%
df_test.head()
# Out:
#                                                 text label
# 0  WASHINGTON (Reuters) U.S. Defense Secretary Ji...  real
# 1  SAO PAULO (Reuters) Brazilian federal Judge rg...  real
# 2  Tune Alternate Current Radio Network (ACR) ano...  fake
# 3  COST OBAMAPHONE PROGRAM WENT 50%. WHY:REMEMBER...  fake
# 4  NEW YORK (Reuters) New York City Mayor Bill de...  real

# %%
df_train.loc[df_train.label == 'fake'].sample(10)
# Out:
#                                                     text label
# 7217   staggering expos Newsweek revealed city surrou...  fake
# 13176  watching video, one thing abundantly clear com...  fake
# 14521  video 1985 shown last night Dem debate people ...  fake
# 31302  Women get far away Oklahoma soon possible Chri...  fake
# 14020  YMCA camp Jackson, Michigan forced ten-year-ol...  fake
# 13156  21st Century Wire says..With Christmas season ...  fake
# 6888   Let nobody tell racists options election. raci...  fake
# 15990  RT President Donald Trump spoke CIA Headquarte...  fake
# 34993  lousy 24 hours Donald Trump campaign Make Amer...  fake
# 28262  parents notified death? possible reason could ...  fake

# %% [markdown]
# ### Get the values of DataFrame

# %%
train_labels = df_train['label'].tolist()
train_text = df_train['text'].tolist()

test_labels = df_test['label'].tolist()
test_text = df_test['text'].tolist()

assert len(train_labels) == len(train_text)
assert len(test_labels) == len(test_text)

print("len(train_text) = {}, len(test_text) = {}".format(len(train_text), len(test_text)))
# Out:
# len(train_text) = 35918, len(test_text) = 8980

# %%
def unique(list1):
 
    # initialize a null list
    unique_list = []
 
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    # print list
    for x in unique_list:
        print (x)

# %%
unique(train_labels)
# Out:
# fake
# real

# %% [markdown]
# ### Get values indices

# %%
def format_label_value(labels):
    """
    Formats a list of labels to corresponding numeric values.
    """
    format_label_list = []

    for label in labels:
        if label == "fake":
            format_label_list.append(0)
        elif label == "real":
            format_label_list.append(1)
        
    
    return format_label_list

# %%
train_labels = format_label_value(train_labels)
test_labels = format_label_value(test_labels)

# %%
len(train_labels)
# Out:
# 35918

# %% [markdown]
# ## XLNet Tokenization & Input Formatting

# %% [markdown]
# ### XLNet Tokenization

# %%
from transformers import AutoTokenizer

# Load the BERT tokenizer.
print('Loading XLNet tokenizer...')
tokenizer = AutoTokenizer.from_pretrained('xlnet-base-cased', do_lower_case=True)
# Out:
# Loading XLNet tokenizer...

# %%
# Print the original sentence.
print('Original: ', train_text[0])
print("len(Original) = ", len(train_text[0]))
print("\n")

# Print the sentence split into tokens.
print('Tokenized: ', tokenizer.tokenize(train_text[0]))
print("len(Tokenized) = ", len(tokenizer.tokenize(train_text[0])))
print("\n")

# Print the sentence mapped to token ids.
print('Token IDs: ', tokenizer.convert_tokens_to_ids(tokenizer.tokenize(train_text[0])))
print("len(Token IDs) = ", len(tokenizer.convert_tokens_to_ids(tokenizer.tokenize(train_text[0]))))
print("\n")
# Out:
# Original:  anyone actually believe possible Barack Hussein Obama person America (with maybe exception Valerie Jarrett) see horrible, lopsided dangerous deal America?Thousands demonstrators gathered Times Square Wednesday evening protest recent landmark nuclear deal Iran.As CBS2 Jessica Schneider reported, 10 thousand rallying solidarity signs voices raised nuclear deal.Protest organizers proclaim: Washington prepared give Iran virtually needs get bomb. release $150 billion Iran result expansion worldwide terror. Former New York Governor, Presidential contender, George Pataki joined chorus voices urging lawmakers block deal. Reject deal. Protect America. Protect Israel protect world freedom, Pataki said.The Stop Iran Rally Coalition claims bi-partisan group also calling Sen. Charles Schumer, saying votes presumptive leader override deal .If deal stopped, New York voters know blame. Sen. Schumer said statement Wednesday ready make decision deal yet. read agreement seeking answers many questions have. make decision, going speak length experts sides, lawmaker said.In Washington, Secretary State John Kerry led back-to-back, closed-door briefings, trying sway lawmakers approve deal curb Iran nuclear program. convinced agreement arrived world powers agreement prevent Iran potential securing nuclear weapon. make region, friends allies safer, make world safer, Kerry said. convinced absence viable alternative absolutely underscores fact. Meanwhile, Israel ambassador U.S. fiercely lobbying lawmakers reject deal. Republicans pledging that. bad deal threatens security American people, going everything possible stop it, said Speaker House Rep. John Boehner. many rally said people country need start listening speaking well. concerned situation here. Nobody wants deal go hoping Obama hear voice American people hoping Congress listen say. hopefully something that, said one protester. feel people really understand main issue. main issue happens 10 years now, happens soon sanctions removed Iran, another protester told Schneider. main terrorist regime world, spreads terrorism around world, responsible deaths Americans well Israelis. Several academic, military, political leaders speak crowd Wednesday night. urge issue transcends politics urging Congress keep sanctions Iran, even means overriding President Barack Obama likely veto legislation deal, Schneider reported. Congress 60 days approve reject deal. Senate hold hearing deal Thursday.Via: New York CBS Local UPDATE: STILL MEDIA COVERAGE THOUSANDS TOOK STREETS NYC PROTEST OBAMA’S DANGEROUS IRAN DEAL
# len(Original) =  2565
#
#
, 2602, 4242, 29662, 648, 9, 2608, 19, 702, 4476, 128, 9, 83, 9, 20807, 13259, 4208, 8006, 629, 9, 2760, 26384, 29, 9, 948, 629, 15740, 470, 242, 104, 19, 223, 931, 498, 829, 36, 19, 42, 8368, 509, 3861, 9, 408, 1923, 3779, 1357, 9, 142, 3789, 42, 104, 234, 214, 467, 5691, 2777, 143, 9, 2206, 1023, 193, 9, 14391, 1578, 629, 216, 3615, 1413, 1388, 1025, 242, 104, 3615, 1119, 4020, 248, 9, 9700, 359, 29, 19, 42, 65, 2924, 118, 9, 567, 104, 343, 1111, 587, 671, 9, 587, 671, 3398, 241, 123, 145, 19, 3398, 802, 3811, 2394, 1241, 19, 245, 2924, 118, 258, 20535, 9, 587, 2948, 3061, 185, 19, 1912, 23, 3140, 199, 185, 19, 1553, 3945, 1644, 143, 7531, 9, 3172, 2550, 19, 370, 19, 413, 783, 2040, 2264, 384, 391, 9, 6807, 671, 24327, 23, 2523, 8546, 1119, 435, 3811, 1241, 19, 176, 731, 95, 5733, 56, 328, 6451, 1413, 774, 9045, 2592, 629, 19, 20535, 550, 9, 1119, 1639, 307, 7019, 8006, 629, 9, 1477, 859, 2243, 629, 389, 9, 1142, 780, 60, 158, 313, 6444, 4676, 29105, 60, 7843, 15332, 21770, 330, 23590, 16345, 430, 9580, 2023, 18190, 83, 5964, 11948, 7843, 14900, 6519, 21574, 13673, 658, 9726, 17, 12190, 20858, 165, 83, 347, 21360, 695, 5771, 2023, 35, 21620, 10241, 5040]
# len(Token IDs) =  472

# %% [markdown]
# ### Input Formatting for XLNet

# %%
import logging

# Set logger to avoid warning `token indices sequence length is longer than the specified maximum sequence length for this model (1017 > 512)`
logging.getLogger("transformers.tokenization_utils").setLevel(logging.ERROR)


def text_to_id(tokenizer, text_list):
    """
    It is a function to transform text to id.
    # `encode` will:
    #   (1) Tokenize the sentence.
    #   (2) Prepend the `[CLS]` token to the start.
    #   (3) Append the `[SEP]` token to the end.
    #   (4) Map tokens to their IDs.
    """
    ids_list = []
    
    for item in text_list:
        # Sentence to id and add [CLS] and [SEP]
        encoded_item = tokenizer.encode(item, add_special_tokens=True)
        ids_list.append(encoded_item)
    
    return ids_list

# %%
for i in range(len(train_text)):
    if not isinstance(train_text[i], str):
        train_text[i] = str(train_text[i])

# %%
for i in range(len(test_text)):
    if not isinstance(test_text[i], str):
        test_text[i] = str(test_text[i])

# %%
train_text_ids = text_to_id(tokenizer, train_text)
test_text_ids = text_to_id(tokenizer, test_text)


# Print sentence 0, now as a list of IDs.
print('Original: {}\n'.format(train_text[0]))
print('Token IDs: {}\n'.format(train_text_ids[0]))
print("len(train_text_ids) = {}\n".format(len(train_text_ids)))
print("len(test_text_ids) = {}".format(len(test_text_ids)))
# Out:
# Original: anyone actually believe possible Barack Hussein Obama person America (with maybe exception Valerie Jarrett) see horrible, lopsided dangerous deal America?Thousands demonstrators gathered Times Square Wednesday evening protest recent landmark nuclear deal Iran.As CBS2 Jessica Schneider reported, 10 thousand rallying solidarity signs voices raised nuclear deal.Protest organizers proclaim: Washington prepared give Iran virtually needs get bomb. release $150 billion Iran result expansion worldwide terror. Former New York Governor, Presidential contender, George Pataki joined chorus voices urging lawmakers block deal. Re
5767, 42, 9, 5503, 5114, 12283, 2602, 4242, 29662, 648, 9, 2608, 19, 702, 4476, 128, 9, 83, 9, 20807, 13259, 4208, 8006, 629, 9, 2760, 26384, 29, 9, 948, 629, 15740, 470, 242, 104, 19, 223, 931, 498, 829, 36, 19, 42, 8368, 509, 3861, 9, 408, 1923, 3779, 1357, 9, 142, 3789, 42, 104, 234, 214, 467, 5691, 2777, 143, 9, 2206, 1023, 193, 9, 14391, 1578, 629, 216, 3615, 1413, 1388, 1025, 242, 104, 3615, 1119, 4020, 248, 9, 9700, 359, 29, 19, 42, 65, 2924, 118, 9, 567, 104, 343, 1111, 587, 671, 9, 587, 671, 3398, 241, 123, 145, 19, 3398, 802, 3811, 2394, 1241, 19, 245, 2924, 118, 258, 20535, 9, 587, 2948, 3061, 185, 19, 1912, 23, 3140, 199, 185, 19, 1553, 3945, 1644, 143, 7531, 9, 3172, 2550, 19, 370, 19, 413, 783, 2040, 2264, 384, 391, 9, 6807, 671, 24327, 23, 2523, 8546, 1119, 435, 3811, 1241, 19, 176, 731, 95, 5733, 56, 328, 6451, 1413, 774, 9045, 2592, 629, 19, 20535, 550, 9, 1119, 1639, 307, 7019, 8006, 629, 9, 1477, 859, 2243, 629, 389, 9, 1142, 780, 60, 158, 313, 6444, 4676, 29105, 60, 7843, 15332, 21770, 330, 23590, 16345, 430, 9580, 2023, 18190, 83, 5964, 11948, 7843, 14900, 6519, 21574, 13673, 658, 9726, 17, 12190, 20858, 165, 83, 347, 21360, 695, 5771, 2023, 35, 21620, 10241, 5040, 4, 3]
#
# len(train_text_ids) = 35918
#
# len(test_text_ids) = 8980

# %%
print('Train: max sentence length: ', max([len(sen) for sen in train_text_ids]))
print('Train: Min sentence length: ', min([len(sen) for sen in train_text_ids]))
print('Test: max sentence length: ', max([len(sen) for sen in test_text_ids]))
print('Test: Min sentence length: ', min([len(sen) for sen in test_text_ids]))
# Out:
# Train: max sentence length:  7330
# Train: Min sentence length:  4
# Test: max sentence length:  6838
# Test: Min sentence length:  4

# %% [markdown]
# ### Padding & Truncating

# %%
def padding_truncating(input_ids_list, max_length):
    """
    It is a function to perform padding and truncating
    @param input_ids_list: <List> text_ids
    @param max_length: <Integer> the number we wanna the sentence to be padding or truncating
    @return: processed input_ids_list
    """
    processed_input_ids_list = []
    for item in input_ids_list:
        seq_list = []
        
        if len(item) < max_length:
            # Define a seq_list with the length of max_length
            seq_list = [0] * (max_length - len(item))
            item = item + seq_list
        
        elif len(item) >= max_length:
            item = item[:max_length]
            
        processed_input_ids_list.append(item)
    
    return processed_input_ids_list

# %%
train_padding_list = padding_truncating(train_text_ids, max_length=50)
test_padding_list = padding_truncating(test_text_ids, max_length=50)

# %% [markdown]
# ### Attention Masks

# %%
def get_attention_masks(pad_input_ids_list):
    """
    It is a function to get attention masks:
    
    - If a token ID is 0, then it's padding, set the mask to 0.
    - If a token ID is > 0, then it's a real token, set the mask to 1.
    """
    attention_masks_list = []
    
    for item in pad_input_ids_list:
        
        mask_list = []
        for subitem in item:
            if subitem > 0:
                mask_list.append(1)
            else:
                mask_list.append(0)
        attention_masks_list.append(mask_list)
    
    return attention_masks_list

# %%
train_attention_masks = get_attention_masks(train_padding_list)
test_attention_masks = get_attention_masks(test_padding_list)

assert len(train_text) == len(train_labels) == len(train_attention_masks) == len(train_padding_list), "Training data length mismatch"
assert len(test_text) == len(test_labels) == len(test_attention_masks) == len(test_padding_list), "Testing data length mismatch"

# %%
print(len(train_text), len(train_labels), len(train_attention_masks), len(train_padding_list))
# Out:
# 35918 35918 35918 35918

# %% [markdown]
# ### Split train dataset into train_dataset and validation_dataset

# %%
from sklearn.model_selection import train_test_split

# Use 90% for training and 10% for validation.
train_padding_list, validation_padding_list, train_labels, validation_labels, train_attention_masks, validation_attention_masks = train_test_split(train_padding_list, train_labels, train_attention_masks, random_state=2020, test_size=0.1)

# %%
assert len(train_labels) == len(train_attention_masks) == len(train_padding_list)
assert len(validation_labels) == len(validation_attention_masks) == len(validation_padding_list)
assert len(test_labels) == len(test_attention_masks) == len(test_padding_list)

# %%
print("len(train_labels) = {}\nlen(validation_labels) = {}\nlen(test_labels) = {}".format(len(train_labels), len(validation_labels), len(test_labels)))
# Out:
# len(train_labels) = 32326
# len(validation_labels) = 3592
# len(test_labels) = 8980

# %% [markdown]
# ### Convert to Dataset

# %% [markdown]
# Convert all the List objects to tensor

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# Convert all inputs and labels into torch tensors, the required datatype for our model.
train_inputs = torch.tensor(train_padding_list)
validation_inputs = torch.tensor(validation_padding_list)
test_inputs = torch.tensor(test_padding_list)

train_labels = torch.tensor(train_labels)
validation_labels = torch.tensor(validation_labels)
test_labels = torch.tensor(test_labels)

train_masks = torch.tensor(train_attention_masks)
validation_masks = torch.tensor(validation_attention_masks)
test_masks = torch.tensor(test_attention_masks)

# %% [markdown]
# Form the Dataset with torch.tensor

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

# The DataLoader needs to know our batch size for training, so we specify it 
# here.
# For fine-tuning BERT on a specific task, the authors recommend a batch size of 16 or 32.

batch_size = 16

# Create the DataLoader for our training set.
train_data = TensorDataset(train_inputs, train_masks, train_labels)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

# Create the DataLoader for our validation set.
validation_data = TensorDataset(validation_inputs, validation_masks, validation_labels)
validation_sampler = RandomSampler(validation_data)
validation_dataloader = DataLoader(validation_data, sampler=validation_sampler, batch_size=batch_size)

# Create the DataLoader for our test set.
test_data = TensorDataset(test_inputs, test_masks, test_labels)
test_sampler = SequentialSampler(test_data)
test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_size)

# %% [markdown]
# ## Train XLNet Text Classification Model

# %%
from transformers import XLNetForSequenceClassification, AdamW, LongformerConfig
import torch

# Load BertForSequenceClassification, the pretrained BERT model
model = XLNetForSequenceClassification.from_pretrained(
    "xlnet-base-cased",  # Use the 12-layer BERT model, with an uncased vocab.
     num_labels = 2,      # The number of output labels -- 2 for binary classification.
                    # You can increase this for multi-class tasks.   
     output_attentions = False, # Whether the model returns attentions weights.
     output_hidden_states = False, # Whether the model returns all hidden-states.
)

model.to(device)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/467M [00:00<?, ?B/s]
# Some weights of the model checkpoint at xlnet-base-cased were not used when initializing XLNetForSequenceClassification: ['lm_loss.bias', 'lm_loss.weight']
# - This IS expected if you are initializing XLNetForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLNetForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['logits_proj.bias', 'sequence_summary.summary.bias', 'sequence_summary.summary.weight', 'logits_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# XLNetForSequenceClassification(
#   (transformer): XLNetModel(
#     (word_embedding): Embedding(32000, 768)
#     (layer): ModuleList(
#       (0-11): 12 x XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation_function): GELUActivation()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (sequence_summary): SequenceSummary(
#     (summary): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#     (first_dropout): Identity()
#     (last_dropout): Dropout(p=0.1, inplace=False)
#   )
#   (logits_proj): Linear(in_features=768, out_features=2, bias=True)
# )

# %% [markdown]
# ### Optimizer & Learning Rate Scheduler

# %%
# Note: AdamW is a class from the huggingface library (as opposed to pytorch) 
# I believe the 'W' stands for 'Weight Decay fix"
optimizer = AdamW(model.parameters(),
                  lr = 5e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
from transformers import get_linear_schedule_with_warmup

# Number of training epochs (authors recommend between 2 and 4)
epochs = 4

# Total number of training steps is number of batches * number of epochs.
total_steps = len(train_dataloader) * epochs
print("total_steps = {}".format(total_steps))

# Create the learning rate scheduler.
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0, # Default value in run_glue.py
                                            num_training_steps = total_steps)
# Out:
# total_steps = 8084

# %% [markdown]
# ### Train

# %%
import numpy as np

# Function to calculate the accuracy of our predictions vs labels
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
import time
import datetime

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import random

# Set the seed value all over the place to make this reproducible.
seed_val = 12345

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)

# Store the average loss after each epoch so we can plot them.
loss_values = []

# For each epoch...
for epoch_i in range(epochs):
    
    ##########################################
    #               Training                 #
    ##########################################
    
    # Perform one full pass over the training set.

    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    # Measure how long the training epoch takes.
    t0 = time.time()

    # Reset the total loss for this epoch.
    total_loss = 0

    # Put the model into training mode. Don't be mislead--the call to 
    # `train` just changes the *mode*, it doesn't *perform* the training.
    # `dropout` and `batchnorm` layers behave differently during training
    # vs. test (source: https://stackoverflow.com/questions/51433378/what-does-model-train-do-in-pytorch)
    model.train()

    # For each batch of training data...
    for step, batch in enumerate(train_dataloader):

        # Progress update every 10 batches.
        if step % 10 == 0 and not step == 0:
            # Calculate elapsed time in minutes.
            elapsed = format_time(time.time() - t0)
            
            # Report progress.
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))

        # Unpack this training batch from our dataloader. 
        # `batch` contains three pytorch tensors:
        #   [0]: input ids 
        #   [1]: attention masks
        #   [2]: labels 
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        # Clear the gradients.
        model.zero_grad()        

        # Perform a forward pass (evaluate the model on this training batch).
        # This will return the loss (rather than the model output) because we have provided the `labels`.
        outputs = model(b_input_ids, 
                        token_type_ids=None, 
                        attention_mask=b_input_mask, 
                        labels=b_labels)
        
        # The call to `model` always returns a tuple, so we need to pull the 
        # loss value out of the tuple.
        loss = outputs[0]

        # Accumulate the training loss over all of the batches so that we can calculate the average loss at the end. 
        # `loss` is a Tensor containing a single value; the `.item()` function just returns the Python value from the tensor.
        total_loss += loss.item()

        # Perform a `backward` pass to calculate the gradients.
        loss.backward()

        # Clip the norm of the gradients to 1.0.
        # This is to help prevent the "exploding gradients" problem.
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # Update parameters and take a step using the computed gradient.
        # The optimizer dictates the "update rule"--how the parameters are modified based on their gradients, the learning rate, etc.
        optimizer.step()

        # Update the learning rate.
        scheduler.step()

    # Calculate the average loss over the training data.
    avg_train_loss = total_loss / len(train_dataloader)            
    
    # Store the loss value for plotting the learning curve.
    loss_values.append(avg_train_loss)

    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epcoh took: {:}".format(format_time(time.time() - t0)))
        
        
    ##########################################
    #               Validation               #
    ##########################################
    # After the completion of each training epoch, measure our performance on our validation set.

    print("")
    print("Running Validation...")

    t0 = time.time()

    # Put the model in evaluation mode--the dropout layers behave differently during evaluation.
    model.eval()

    # Tracking variables 
    eval_loss, eval_accuracy = 0, 0
    nb_eval_steps, nb_eval_examples = 0, 0

    # Evaluate data for one epoch
    for batch in validation_dataloader:
        
        # Add batch to device
        batch = tuple(t.to(device) for t in batch)
        
        # Unpack the inputs from our dataloader
        b_input_ids, b_input_mask, b_labels = batch
        
        # Telling the model not to compute or store gradients, saving memory and speeding up validation
        with torch.no_grad():        

            # Forward pass, calculate logit predictions.
            # This will return the logits rather than the loss because we have not provided labels.
            # token_type_ids is the same as the "segment ids", which differentiates sentence 1 and 2 in 2-sentence tasks.
            # The documentation for this `model` function is here: 
            # https://huggingface.co/transformers/v2.2.0/model_doc/bert.html#transformers.BertForSequenceClassification
            outputs = model(b_input_ids, 
                            token_type_ids=None, 
                            attention_mask=b_input_mask)
        
        # Get the "logits" output by the model. The "logits" are the output
        # values prior to applying an activation function like the softmax.
        logits = outputs[0]

        # Move logits and labels to CPU
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        
        # Calculate the accuracy for this batch of test sentences.
        # flat_accuracy(y_pred, y_true)
        tmp_eval_accuracy = flat_accuracy(logits, label_ids)
        
        # Accumulate the total accuracy.
        eval_accuracy += tmp_eval_accuracy

        # Track the number of batches
        nb_eval_steps += 1

    # Report the final accuracy for this validation run.
    print("  Accuracy: {0:.2f}".format(eval_accuracy/nb_eval_steps))
    print("  Validation took: {:}".format(format_time(time.time() - t0)))

print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 4 ========
# Training...
#   Batch    10  of  2,021.    Elapsed: 0:00:05.
#   Batch    20  of  2,021.    Elapsed: 0:00:07.
#   Batch    30  of  2,021.    Elapsed: 0:00:08.
#   Batch    40  of  2,021.    Elapsed: 0:00:10.
#   Batch    50  of  2,021.    Elapsed: 0:00:12.
#   Batch    60  of  2,021.    Elapsed: 0:00:14.
#   Batch    70  of  2,021.    Elapsed: 0:00:15.
#   Batch    80  of  2,021.    Elapsed: 0:00:17.
#   Batch    90  of  2,021.    Elapsed: 0:00:19.
#   Batch   100  of  2,021.    Elapsed: 0:00:20.
#   Batch   110  of  2,021.    Elapsed: 0:00:22.
#   Batch   120  of  2,021.    Elapsed: 0:00:24.
#   Batch   130  of  2,021.    Elapsed: 0:00:26.
#   Batch   140  of  2,021.    Elapsed: 0:00:27.
#   Batch   150  of  2,021.    Elapsed: 0:00:29.
#   Batch   160  of  2,021.    Elapsed: 0:00:31.
#   Batch   170  of  2,021.    Elapsed: 0:00:33.
#   Batch   180  of  2,021.    Elapsed: 0:00:35.
#   Batch   190  of  2,021.    Elapsed: 0:00:36.
#   Batch   200  of  2,021.    Elapsed: 0:00:38.
#   Batch   210  of  2,021.    Elapsed: 0:00:40.
#   Batch 1,820  of  2,021.    Elapsed: 0:05:50.
#   Batch 1,830  of  2,021.    Elapsed: 0:05:52.
#   Batch 1,840  of  2,021.    Elapsed: 0:05:54.
#   Batch 1,850  of  2,021.    Elapsed: 0:05:55.
#   Batch 1,860  of  2,021.    Elapsed: 0:05:57.
#   Batch 1,870  of  2,021.    Elapsed: 0:05:59.
#   Batch 1,880  of  2,021.    Elapsed: 0:06:01.
#   Batch 1,890  of  2,021.    Elapsed: 0:06:03.
#   Batch 1,900  of  2,021.    Elapsed: 0:06:05.
#   Batch 1,910  of  2,021.    Elapsed: 0:06:07.
#   Batch 1,920  of  2,021.    Elapsed: 0:06:09.
#   Batch 1,930  of  2,021.    Elapsed: 0:06:11.
#   Batch 1,940  of  2,021.    Elapsed: 0:06:13.
#   Batch 1,950  of  2,021.    Elapsed: 0:06:15.
#   Batch 1,960  of  2,021.    Elapsed: 0:06:17.
#   Batch 1,970  of  2,021.    Elapsed: 0:06:19.
#   Batch 1,980  of  2,021.    Elapsed: 0:06:20.
#   Batch 1,990  of  2,021.    Elapsed: 0:06:22.
#   Batch 2,000  of  2,021.    Elapsed: 0:06:24.
#   Batch 2,010  of  2,021.    Elapsed: 0:06:26.
#   Batch 2,020  of  2,021.    Elapsed: 0:06:28.
#
#   Average training loss: 0.01
#   Training epcoh took: 0:06:28
#
# Running Validation...
#   Accuracy: 1.00
#   Validation took: 0:00:13
#
# Training complete!

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# Use plot styling from seaborn.
sns.set(style='darkgrid')

# Increase the plot size and font size.
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)

# Plot the learning curve.
plt.plot(loss_values, 'b-o')

# Label the plot.
plt.title("Training loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.show()

# %% [markdown]
# ### Evaluation

# %%
print('Predicting labels for {:,} test sentences...'.format(len(test_inputs)))

# Put model in evaluation mode
model.eval()

# Tracking variables 
predictions, true_labels = [], []

# Predict 
total_correct = 0
for idx, batch in enumerate(test_dataloader):
    
    print("Batch {}".format(idx + 1))
    
    # Add batch to device
    batch = tuple(t.to(device) for t in batch)
  
    # Unpack the inputs from our dataloader
    b_input_ids, b_input_mask, b_labels = batch
  
    # Telling the model not to compute or store gradients, saving memory and 
    # speeding up prediction
    with torch.no_grad():
        # Forward pass, calculate logit predictions
        outputs = model(b_input_ids, token_type_ids=None, 
                        attention_mask=b_input_mask)

    # Get the prediction probability
    logits = outputs[0]
    
    # Get the prediction label
    pred = torch.argmax(logits, dim=1)
   
    # Get the number of correct predictions in this batch
    batch_correct = (pred == b_labels).sum().item()
    print("Batch correct = {}\n".format(batch_correct))
    
    # Accumulate the number of correct predictions over all batches
    total_correct += batch_correct
    
    # Append the predicted labels and true labels for this batch
    predictions.append(pred.cpu().numpy())
    true_labels.append(b_labels.cpu().numpy())
    

print('DONE.')
print("Total correct = ", total_correct)
print("Test accuracy = {0:.2f}".format(total_correct / len(test_inputs)))

# Concatenate the predicted labels and true labels over all batches
predictions = np.concatenate(predictions, axis=0)
true_labels = np.concatenate(true_labels, axis=0)

# Print classification report and confusion matrix
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(true_labels, predictions))
print(confusion_matrix(true_labels, predictions))
# Out:
# Predicting labels for 8,980 test sentences...
# Batch 1
# Batch correct = 16
#
# Batch 2
# Batch correct = 16
#
# Batch 3
# Batch correct = 16
#
# Batch 4
# Batch correct = 16
#
# Batch 5
# Batch correct = 16
#
# Batch 6
# Batch correct = 16
#
# Batch 7
# Batch correct = 16
#
# Batch 8
# Batch correct = 16
#
# Batch 9
# Batch correct = 16
#
# Batch 10
# Batch correct = 16
#
# Batch 11
# Batch correct = 16
#
# Batch 12
# Batch correct = 16
#
# Batch 13
# Batch correct = 16
#
# Batch 14
# Batch correct = 16
#
# Batch 15
# Batch correct = 16
#
# Batch 16
# Batch correct = 16
#
# Batch 17
# Batch correct = 16
#
# Batch 18
# Batch correct = 16
#
# Batch 19
# Batch correct = 16
#
# Batch 20
# Batch correct = 16
#
# Batch 21
# Batch correct = 16
#
# Batch 22
# Batch correct = 16
#
# Batch 23
# Batch correct = 16
#
# Batch 24
# Batch correct = 16
#
# Batch 25
# Batch correct = 16
#
# Batch 26
# Batch correct = 16
#
# Batch 27
# Batch correct = 16
#
# Batch 28
# Batch correct = 16
#
# Batch 29
# Batch correct = 16
#
# Batch 30
# Batch correct = 16
#
# Batch 31
# Batch correct = 16
#
# Batch 32
# Batch correct = 16
#
# Batch 33
# Batch correct = 16
#
# Batch 34
# Batch correct = 16
#
# Batch 35
# Batch correct = 16
#
# Batch 36
# Batch correct = 16
#
# Batch 37
# Batch correct = 16
#
# Batch 38
# Batch correct = 16
#
# Batch 39
# Batch correct = 16
#
# Batch 40
# Batch correct = 16
#
# Batch 41
# Batch correct = 16
#
# Batch 42
# Batch correct = 16
#
# Batch 43
# Batch correct = 16
#
# Batch 44
# Batch correct = 16
#
# Batch 45
# Batch correct = 16
#
# Batch 46
# Batch correct = 16
#
# Batch 47
# Batch correct = 16
#
# Batch 48
# Batch correct = 16
#
# Batch 49
# Batch correct = 16
#
# Batch 50
# Batch correct = 16
#
# Batch 51
# Batch correct = 16
#
# Batch 52
# Batch correct = 16
#
# Batch 53
# Batch correct = 16
#
# Batch 54
# Batch correct = 16
#
# Batch 55
# Batch correct = 16
#
# Batch 56
# Batch correct = 16
#
# Batch 57
# Batch correct = 16
#
# Batch 58
# Batch correct = 16
#
# Batch 59
# Batch correct = 16
#
# Batch 60
# Batch correct = 16
#
# Batch 61
# Batch correct = 16
#
# Batch 62
# Batch correct = 16
#
# Batch 63
# Batch correct = 16
#
# Batch 64
# Batch correct = 16
#
# Batch 65
# Batch correct = 16
#
# Batch 66
# Batch correct = 16
#
# Batch 67
# Batch correct = 16
#
# Batch 68
# Batch correct = 16
#
# Batch 69
# Batch correct = 16
#
# Batch 70
# Batch correct = 16
#
# Batch 71
# Batch correct = 16
#
# Batch 72
# Batch correct = 16
#
# Batch 73
# Batch correct = 16
#
# Batch 74
# Batch correct = 16
#
# Batch 75
# Batch correct = 16
#
# Batch 76
# Batch correct = 16
#
# Batch 77
# Batch correct = 16
#
# Batch 78
# Batch correct = 16
#
# Batch 79
# Batch correct = 16
#
# Batch 80
# Batch correct = 16
#
# Batch 81
# Batch correct = 16
#
# Batch 82
# Batch correct = 16
#
# Batch 83
# Batch correct = 16
#
# Batch 84
# Batch correct = 16
#
# Batch 85
# Batch correct = 16
#
# Batch 86
# Batch correct = 16
#
# Batch 87
# Batch correct = 16
#
# Batch 88
# Batch correct = 16
#
# Batch 89
# Batch correct = 16
#
# Batch 90
# Batch correct = 16
#
# Batch 91
# Batch correct = 16
#
# Batch 92
# Batch correct = 16
#
# Batch 93
# Batch correct = 16
#
# Batch 94
# Batch correct = 16
#
# Batch 95
# Batch correct = 16
#
# Batch 96
# Batch correct = 16
#
# Batch 97
# Batch correct = 16
#
# Batch 98
# Batch correct = 16
#
# Batch 99
# Batch correct = 16
#
# Batch 100
# Batch correct = 15
#
# Batch 101
# Batch correct = 16
#
# Batch 102
# Batch correct = 16
#
# Batch 103
# Batch correct = 16
#
# Batch 104
# Batch correct = 16
#
# Batch 105
# Batch correct = 16
#
# Batch 106
# Batch correct = 16
#
# Batch 107
# Batch correct = 16
#
# Batch 108
# Batch correct = 16
#
# Batch 109
# Batch correct = 16
#
# Batch 110
# Batch correct = 16
#
# Batch 111
# Batch correct = 16
#
# Batch 112
# Batch correct = 16
#
# Batch 113
# Batch correct = 16
#
# Batch 114
# Batch correct = 16
#
# Batch 115
# Batch correct = 16
#
# Batch 116
# Batch correct = 16
#
# Batch 117
# Batch correct = 16
#
# Batch 118
# Batch correct = 16
#
# Batch 119
# Batch correct = 16
#
# Batch 120
# Batch correct = 16
#
# Batch 121
# Batch correct = 16
#
# Batch 122
# Batch correct = 16
#
# Batch 123
# Batch correct = 16
#
# Batch 124
# Batch correct = 16
#
# Batch 125
# Batch correct = 16
#
# Batch 126
# Batch correct = 16
#
# Batch 127
# Batch correct = 16
#
# Batch 128
# Batch correct = 16
#
# Batch 129
# Batch correct = 16
#
# Batch 130
# Batch correct = 16
#
# Batch 131
# Batch correct = 16
#
# Batch 132
# Batch correct = 16
#
# Batch 133
# Batch correct = 16
#
# Batch 134
# Batch correct = 16
#
# Batch 135
# Batch correct = 16
#
# Batch 136
# Batch correct = 16
#
# Batch 137
# Batch correct = 16
#
# Batch 138
# Batch correct = 16
#
# Batch 139
# Batch correct = 16
#
# Batch 140
# Batch correct = 16
#
# Batch 141
# Batch correct = 16
#
# Batch 142
# Batch correct = 16
#
# Batch 143
# Batch correct = 16
#
# Batch 144
# Batch correct = 16
#
# Batch 145
# Batch correct = 16
#
# Batch 146
# Batch correct = 15
#
# Batch 147
# Batch correct = 16
#
# Batch 148
# Batch correct = 16
#
# Batch 149
# Batch correct = 16
#
# Batch 150
# Batch correct = 16
#
# Batch 151
# Batch correct = 16
#
# Batch 152
# Batch correct = 16
#
# Batch 153
# Batch correct = 16
#
# Batch 154
# Batch correct = 16
#
# Batch 155
# Batch correct = 16
#
# Batch 156
# Batch correct = 16
#
# Batch 157
# Batch correct = 16
#
# Batch 158
# Batch correct = 16
#
# Batch 159
# Batch correct = 16
#
# Batch 160
# Batch correct = 16
#
# Batch 161
# Batch correct = 16
#
# Batch 162
# Batch correct = 16
#
# Batch 163
# Batch correct = 16
#
# Batch 164
# Batch correct = 16
#
# Batch 165
# Batch correct = 16
#
# Batch 166
# Batch correct = 16
#
# Batch 167
# Batch correct = 16
#
# Batch 168
# Batch correct = 15
#
# Batch 169
# Batch correct = 16
#
# Batch 170
# Batch correct = 16
#
# Batch 171
# Batch correct = 15
#
# Batch 172
# Batch correct = 16
#
# Batch 173
# Batch correct = 16
#
# Batch 174
# Batch correct = 16
#
# Batch 175
# Batch correct = 16
#
# Batch 176
# Batch correct = 16
#
# Batch 177
# Batch correct = 16
#
# Batch 178
# Batch correct = 16
#
# Batch 179
# Batch correct = 16
#
# Batch 180
# Batch correct = 16
#
# Batch 181
# Batch correct = 16
#
# Batch 182
# Batch correct = 16
#
# Batch 183
# Batch correct = 16
#
# Batch 184
# Batch correct = 16
#
# Batch 185
# Batch correct = 16
#
# Batch 186
# Batch correct = 16
#
# Batch 187
# Batch correct = 15
#
# Batch 188
# Batch correct = 16
#
# Batch 189
# Batch correct = 16
#
# Batch 190
# Batch correct = 16
#
# Batch 191
# Batch correct = 16
#
# Batch 192
# Batch correct = 16
#
# Batch 193
# Batch correct = 16
#
# Batch 194
# Batch correct = 16
#
# Batch 195
# Batch correct = 16
#
# Batch 196
# Batch correct = 16
#
# Batch 197
# Batch correct = 16
#
# Batch 198
# Batch correct = 16
#
# Batch 199
# Batch correct = 16
#
# Batch 200
# Batch correct = 16
#
# Batch 201
# Batch correct = 16
#
# Batch 202
# Batch correct = 16
#
# Batch 203
# Batch correct = 16
#
# Batch 204
# Batch correct = 16
#
# Batch 205
# Batch correct = 16
#
# Batch 206
# Batch correct = 16
#
# Batch 207
# Batch correct = 16
#
# Batch 208
# Batch correct = 16
#
# Batch 209
# Batch correct = 16
#
# Batch 210
# Batch correct = 16
#
# Batch 211
# Batch correct = 16
#
# Batch 212
# Batch correct = 16
#
# Batch 213
# Batch correct = 16
#
# Batch 214
# Batch correct = 16
#
# Batch 215
# Batch correct = 16
#
# Batch 216
# Batch correct = 16
#
# Batch 217
# Batch correct = 16
#
# Batch 218
# Batch correct = 16
#
# Batch 219
# Batch correct = 16
#
# Batch 220
# Batch correct = 16
#
# Batch 221
# Batch correct = 15
#
# Batch 222
# Batch correct = 16
#
# Batch 223
# Batch correct = 16
#
# Batch 224
# Batch correct = 16
#
# Batch 225
# Batch correct = 16
#
# Batch 226
# Batch correct = 16
#
# Batch 227
# Batch correct = 16
#
# Batch 228
# Batch correct = 16
#
# Batch 229
# Batch correct = 16
#
# Batch 230
# Batch correct = 15
#
# Batch 231
# Batch correct = 16
#
# Batch 232
# Batch correct = 16
#
# Batch 233
# Batch correct = 16
#
# Batch 234
# Batch correct = 16
#
# Batch 235
# Batch correct = 16
#
# Batch 236
# Batch correct = 16
#
# Batch 237
# Batch correct = 16
#
# Batch 238
# Batch correct = 16
#
# Batch 239
# Batch correct = 16
#
# Batch 240
# Batch correct = 16
#
# Batch 241
# Batch correct = 16
#
# Batch 242
# Batch correct = 16
#
# Batch 243
# Batch correct = 16
#
# Batch 244
# Batch correct = 16
#
# Batch 245
# Batch correct = 16
#
# Batch 246
# Batch correct = 16
#
# Batch 247
# Batch correct = 16
#
# Batch 248
# Batch correct = 16
#
# Batch 249
# Batch correct = 16
#
# Batch 250
# Batch correct = 16
#
# Batch 251
# Batch correct = 16
#
# Batch 252
# Batch correct = 16
#
# Batch 253
# Batch correct = 16
#
# Batch 254
# Batch correct = 16
#
# Batch 255
# Batch correct = 16
#
# Batch 256
# Batch correct = 16
#
# Batch 257
# Batch correct = 16
#
# Batch 258
# Batch correct = 15
#
# Batch 259
# Batch correct = 16
#
# Batch 260
# Batch correct = 16
#
# Batch 261
# Batch correct = 16
#
# Batch 262
# Batch correct = 16
#
# Batch 263
# Batch correct = 16
#
# Batch 264
# Batch correct = 16
#
# Batch 265
# Batch correct = 16
#
# Batch 266
# Batch correct = 16
#
# Batch 267
# Batch correct = 16
#
# Batch 268
# Batch correct = 16
#
# Batch 269
# Batch correct = 16
#
# Batch 270
# Batch correct = 16
#
# Batch 271
# Batch correct = 16
#
# Batch 272
# Batch correct = 16
#
# Batch 273
# Batch correct = 16
#
# Batch 274
# Batch correct = 16
#
# Batch 275
# Batch correct = 16
#
# Batch 276
# Batch correct = 15
#
# Batch 277
# Batch correct = 16
#
# Batch 278
# Batch correct = 16
#
# Batch 279
# Batch correct = 16
#
# Batch 280
# Batch correct = 15
#
# Batch 281
# Batch correct = 16
#
# Batch 282
# Batch correct = 16
#
# Batch 283
# Batch correct = 16
#
# Batch 284
# Batch correct = 16
#
# Batch 285
# Batch correct = 16
#
# Batch 286
# Batch correct = 16
#
# Batch 287
# Batch correct = 16
#
# Batch 288
# Batch correct = 16
#
# Batch 289
# Batch correct = 16
#
# Batch 290
# Batch correct = 16
#
# Batch 291
# Batch correct = 15
#
# Batch 292
# Batch correct = 16
#
# Batch 293
# Batch correct = 16
#
# Batch 294
# Batch correct = 16
#
# Batch 295
# Batch correct = 16
#
# Batch 296
# Batch correct = 16
#
# Batch 297
# Batch correct = 16
#
# Batch 298
# Batch correct = 15
#
# Batch 299
# Batch correct = 16
#
# Batch 300
# Batch correct = 16
#
# Batch 301
# Batch correct = 16
#
# Batch 302
# Batch correct = 16
#
# Batch 303
# Batch correct = 16
#
# Batch 304
# Batch correct = 16
#
# Batch 305
# Batch correct = 16
#
# Batch 306
# Batch correct = 16
#
# Batch 307
# Batch correct = 16
#
# Batch 308
# Batch correct = 16
#
# Batch 309
# Batch correct = 16
#
# Batch 310
# Batch correct = 16
#
# Batch 311
# Batch correct = 16
#
# Batch 312
# Batch correct = 16
#
# Batch 313
# Batch correct = 16
#
# Batch 314
# Batch correct = 16
#
# Batch 315
# Batch correct = 16
#
# Batch 316
# Batch correct = 16
#
# Batch 317
# Batch correct = 16
#
# Batch 318
# Batch correct = 16
#
# Batch 319
# Batch correct = 15
#
# Batch 320
# Batch correct = 16
#
# Batch 321
# Batch correct = 16
#
# Batch 322
# Batch correct = 16
#
# Batch 323
# Batch correct = 16
#
# Batch 324
# Batch correct = 16
#
# Batch 325
# Batch correct = 16
#
# Batch 326
# Batch correct = 16
#
# Batch 327
# Batch correct = 16
#
# Batch 328
# Batch correct = 16
#
# Batch 329
# Batch correct = 16
#
# Batch 330
# Batch correct = 16
#
# Batch 331
# Batch correct = 16
#
# Batch 332
# Batch correct = 16
#
# Batch 333
# Batch correct = 16
#
# Batch 334
# Batch correct = 16
#
# Batch 335
# Batch correct = 16
#
# Batch 336
# Batch correct = 16
#
# Batch 337
# Batch correct = 16
#
# Batch 338
# Batch correct = 16
#
# Batch 339
# Batch correct = 16
#
# Batch 340
# Batch correct = 16
#
# Batch 341
# Batch correct = 16
#
# Batch 342
# Batch correct = 16
#
# Batch 343
# Batch correct = 16
#
# Batch 344
# Batch correct = 16
#
# Batch 345
# Batch correct = 16
#
# Batch 346
# Batch correct = 16
#
# Batch 347
# Batch correct = 16
#
# Batch 348
# Batch correct = 16
#
# Batch 349
# Batch correct = 16
#
# Batch 350
# Batch correct = 16
#
# Batch 351
# Batch correct = 16
#
# Batch 352
# Batch correct = 16
#
# Batch 353
# Batch correct = 16
#
# Batch 354
# Batch correct = 16
#
# Batch 355
# Batch correct = 16
#
# Batch 356
# Batch correct = 16
#
# Batch 357
# Batch correct = 16
#
# Batch 358
# Batch correct = 16
#
# Batch 359
# Batch correct = 16
#
# Batch 360
# Batch correct = 16
#
# Batch 361
# Batch correct = 15
#
# Batch 362
# Batch correct = 16
#
# Batch 363
# Batch correct = 16
#
# Batch 364
# Batch correct = 16
#
# Batch 365
# Batch correct = 16
#
# Batch 366
# Batch correct = 16
#
# Batch 367
# Batch correct = 16
#
# Batch 368
# Batch correct = 16
#
# Batch 369
# Batch correct = 16
#
# Batch 370
# Batch correct = 16
#
# Batch 371
# Batch correct = 16
#
# Batch 372
# Batch correct = 16
#
# Batch 373
# Batch correct = 16
#
# Batch 374
# Batch correct = 16
#
# Batch 375
# Batch correct = 16
#
# Batch 376
# Batch correct = 16
#
# Batch 377
# Batch correct = 16
#
# Batch 378
# Batch correct = 16
#
# Batch 379
# Batch correct = 16
#
# Batch 380
# Batch correct = 16
#
# Batch 381
# Batch correct = 15
#
# Batch 382
# Batch correct = 16
#
# Batch 383
# Batch correct = 16
#
# Batch 384
# Batch correct = 16
#
# Batch 385
# Batch correct = 16
#
# Batch 386
# Batch correct = 16
#
# Batch 387
# Batch correct = 16
#
# Batch 388
# Batch correct = 16
#
# Batch 389
# Batch correct = 16
#
# Batch 390
# Batch correct = 16
#
# Batch 391
# Batch correct = 16
#
# Batch 392
# Batch correct = 16
#
# Batch 393
# Batch correct = 16
#
# Batch 394
# Batch correct = 16
#
# Batch 395
# Batch correct = 16
#
# Batch 396
# Batch correct = 16
#
# Batch 397
# Batch correct = 15
#
# Batch 398
# Batch correct = 16
#
# Batch 399
# Batch correct = 16
#
# Batch 400
# Batch correct = 16
#
# Batch 401
# Batch correct = 16
#
# Batch 402
# Batch correct = 16
#
# Batch 403
# Batch correct = 16
#
# Batch 404
# Batch correct = 16
#
# Batch 405
# Batch correct = 16
#
# Batch 406
# Batch correct = 16
#
# Batch 407
# Batch correct = 16
#
# Batch 408
# Batch correct = 16
#
# Batch 409
# Batch correct = 16
#
# Batch 410
# Batch correct = 16
#
# Batch 411
# Batch correct = 16
#
# Batch 412
# Batch correct = 16
#
# Batch 413
# Batch correct = 16
#
# Batch 414
# Batch correct = 16
#
# Batch 415
# Batch correct = 16
#
# Batch 416
# Batch correct = 16
#
# Batch 417
# Batch correct = 16
#
# Batch 418
# Batch correct = 16
#
# Batch 419
# Batch correct = 16
#
# Batch 420
# Batch correct = 16
#
# Batch 421
# Batch correct = 15
#
# Batch 422
# Batch correct = 16
#
# Batch 423
# Batch correct = 16
#
# Batch 424
# Batch correct = 16
#
# Batch 425
# Batch correct = 16
#
# Batch 426
# Batch correct = 16
#
# Batch 427
# Batch correct = 16
#
# Batch 428
# Batch correct = 16
#
# Batch 429
# Batch correct = 16
#
# Batch 430
# Batch correct = 16
#
# Batch 431
# Batch correct = 16
#
# Batch 432
# Batch correct = 16
#
# Batch 433
# Batch correct = 16
#
# Batch 434
# Batch correct = 16
#
# Batch 435
# Batch correct = 16
#
# Batch 436
# Batch correct = 16
#
# Batch 437
# Batch correct = 16
#
# Batch 438
# Batch correct = 16
#
# Batch 439
# Batch correct = 16
#
# Batch 440
# Batch correct = 16
#
# Batch 441
# Batch correct = 16
#
# Batch 442
# Batch correct = 16
#
# Batch 443
# Batch correct = 16
#
# Batch 444
# Batch correct = 16
#
# Batch 445
# Batch correct = 16
#
# Batch 446
# Batch correct = 16
#
# Batch 447
# Batch correct = 16
#
# Batch 448
# Batch correct = 16
#
# Batch 449
# Batch correct = 16
#
# Batch 450
# Batch correct = 16
#
# Batch 451
# Batch correct = 16
#
# Batch 452
# Batch correct = 16
#
# Batch 453
# Batch correct = 16
#
# Batch 454
# Batch correct = 16
#
# Batch 455
# Batch correct = 16
#
# Batch 456
# Batch correct = 16
#
# Batch 457
# Batch correct = 16
#
# Batch 458
# Batch correct = 16
#
# Batch 459
# Batch correct = 16
#
# Batch 460
# Batch correct = 16
#
# Batch 461
# Batch correct = 16
#
# Batch 462
# Batch correct = 16
#
# Batch 463
# Batch correct = 16
#
# Batch 464
# Batch correct = 16
#
# Batch 465
# Batch correct = 16
#
# Batch 466
# Batch correct = 16
#
# Batch 467
# Batch correct = 16
#
# Batch 468
# Batch correct = 16
#
# Batch 469
# Batch correct = 16
#
# Batch 470
# Batch correct = 16
#
# Batch 471
# Batch correct = 16
#
# Batch 472
# Batch correct = 16
#
# Batch 473
# Batch correct = 16
#
# Batch 474
# Batch correct = 16
#
# Batch 475
# Batch correct = 16
#
# Batch 476
# Batch correct = 16
#
# Batch 477
# Batch correct = 16
#
# Batch 478
# Batch correct = 16
#
# Batch 479
# Batch correct = 16
#
# Batch 480
# Batch correct = 16
#
# Batch 481
# Batch correct = 16
#
# Batch 482
# Batch correct = 16
#
# Batch 483
# Batch correct = 16
#
# Batch 484
# Batch correct = 16
#
# Batch 485
# Batch correct = 16
#
# Batch 486
# Batch correct = 16
#
# Batch 487
# Batch correct = 16
#
# Batch 488
# Batch correct = 16
#
# Batch 489
# Batch correct = 16
#
# Batch 490
# Batch correct = 16
#
# Batch 491
# Batch correct = 16
#
# Batch 492
# Batch correct = 16
#
# Batch 493
# Batch correct = 16
#
# Batch 494
# Batch correct = 16
#
# Batch 495
# Batch correct = 16
#
# Batch 496
# Batch correct = 16
#
# Batch 497
# Batch correct = 16
#
# Batch 498
# Batch correct = 16
#
# Batch 499
# Batch correct = 16
#
# Batch 500
# Batch correct = 16
#
# Batch 501
# Batch correct = 16
#
# Batch 502
# Batch correct = 16
#
# Batch 503
# Batch correct = 16
#
# Batch 504
# Batch correct = 16
#
# Batch 505
# Batch correct = 16
#
# Batch 506
# Batch correct = 16
#
# Batch 507
# Batch correct = 16
#
# Batch 508
# Batch correct = 16
#
# Batch 509
# Batch correct = 16
#
# Batch 510
# Batch correct = 16
#
# Batch 511
# Batch correct = 16
#
# Batch 512
# Batch correct = 16
#
# Batch 513
# Batch correct = 16
#
# Batch 514
# Batch correct = 16
#
# Batch 515
# Batch correct = 16
#
# Batch 516
# Batch correct = 16
#
# Batch 517
# Batch correct = 16
#
# Batch 518
# Batch correct = 16
#
# Batch 519
# Batch correct = 16
#
# Batch 520
# Batch correct = 16
#
# Batch 521
# Batch correct = 16
#
# Batch 522
# Batch correct = 16
#
# Batch 523
# Batch correct = 16
#
# Batch 524
# Batch correct = 16
#
# Batch 525
# Batch correct = 16
#
# Batch 526
# Batch correct = 16
#
# Batch 527
# Batch correct = 16
#
# Batch 528
# Batch correct = 16
#
# Batch 529
# Batch correct = 16
#
# Batch 530
# Batch correct = 16
#
# Batch 531
# Batch correct = 16
#
# Batch 532
# Batch correct = 16
#
# Batch 533
# Batch correct = 16
#
# Batch 534
# Batch correct = 16
#
# Batch 535
# Batch correct = 16
#
# Batch 536
# Batch correct = 16
#
# Batch 537
# Batch correct = 16
#
# Batch 538
# Batch correct = 16
#
# Batch 539
# Batch correct = 16
#
# Batch 540
# Batch correct = 16
#
# Batch 541
# Batch correct = 16
#
# Batch 542
# Batch correct = 16
#
# Batch 543
# Batch correct = 16
#
# Batch 544
# Batch correct = 16
#
# Batch 545
# Batch correct = 16
#
# Batch 546
# Batch correct = 16
#
# Batch 547
# Batch correct = 16
#
# Batch 548
# Batch correct = 16
#
# Batch 549
# Batch correct = 16
#
# Batch 550
# Batch correct = 16
#
# Batch 551
# Batch correct = 16
#
# Batch 552
# Batch correct = 16
#
# Batch 553
# Batch correct = 16
#
# Batch 554
# Batch correct = 16
#
# Batch 555
# Batch correct = 16
#
# Batch 556
# Batch correct = 16
#
# Batch 557
# Batch correct = 16
#
# Batch 558
# Batch correct = 16
#
# Batch 559
# Batch correct = 16
#
# Batch 560
# Batch correct = 16
#
# Batch 561
# Batch correct = 16
#
# Batch 562
# Batch correct = 4
#
# DONE.
# Total correct =  8963
# Test accuracy = 1.00
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4720
#            1       1.00      1.00      1.00      4260
#
#     accuracy                           1.00      8980
#    macro avg       1.00      1.00      1.00      8980
# weighted avg       1.00      1.00      1.00      8980
#
# [[4711    9]
#  [   8 4252]]
