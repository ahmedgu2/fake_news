# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip3 install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.2-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 52.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 28.2 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 112.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.3 tokenizers-0.13.2 transformers-4.27.2

# %% [markdown]
# # Twitter 2015

# %% [markdown]
# ## Data Pre-processing

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Read dataset file

# %%
import pandas as pd
import numpy as np

train_filename = "/content/drive/MyDrive/NLP Project/Datasets/Twitter2015/tweetstrain2015.csv"
test_filename = "/content/drive/MyDrive/NLP Project/Datasets/Twitter2015/tweetstest2015.csv"

df_train = pd.read_csv(train_filename)
df_test = pd.read_csv(test_filename)

# %%
df_train.columns.values.tolist()
# Out:
# ['Unnamed: 0.1', 'Unnamed: 0', 'tweetId', 'tweetText', 'label']

# %%
df_train = df_train.drop('Unnamed: 0', axis=1)
df_train = df_train.drop('tweetId', axis=1)

# %%
df_test = df_test.drop('Unnamed: 0', axis=1)
df_test = df_test.drop('tweetId', axis=1)

# %%
df_train = df_train.rename(columns={'tweetText': 'text'})
df_test = df_test.rename(columns={'tweetText': 'text'})

# %%
df_train.head()
# Out:
#    Unnamed: 0.1                                               text label
# 0             0  se acuerdan de la pel cula el despu de ana rec...  fake
# 1             1  milenagimon miren sandi en ny tremenda imagen ...  fake
# 2             2  buena la foto del hurac n sandi recuerda la pe...  fake
# 3             3            scari shit hurrican ny http co e jlbufh  fake
# 4             4  fave place world nyc hurrican sandi statueofli...  fake

# %%
df_test.head()
# Out:
#    Unnamed: 0.1                                               text label
# 0             0    kereeen rt shyman eclips iss http co je hcfpvfn  fake
# 1             1  absolut beauti rt shyman eclips iss http co oq...  fake
# 2             2      shyman eclips iss http co c vfboscrj wow amaz  fake
# 3             3                        eclips iss http co en otvsu  fake
# 4             4  ebonfigli clips vue de l iss autr chose http c...  fake

# %%
df_train.loc[df_train.label == 'fake'].sample(10)
# Out:
#        Unnamed: 0.1                                               text label
# 6961           6961  share pic hurricanesandi safe peopl oiga oigae...  fake
# 2391           2391  tiburon en el metro de new jersey por el hurac...  fake
# 13467         13467  christinewark lmao sochi pic like everywher ht...  fake
# 1386           1386                      view n sandi http co ekqebdgn  fake
# 487             487  http co zdd sxlt sandi pic look awesom sure re...  fake
# 622             622  american get soldier gaurd tomb unknown soldie...  fake
# 6544           6544         think game hurrican sandi http co va botvl  fake
# 2417           2417  mt gt gt awesom alrok last night hurrican sand...  fake
# 4627           4627  comparto una imagen real actual de sandi en ny...  fake
# 5929           5929  rt jensiegrist claytonmorri snap pictur lower ...  fake

# %% [markdown]
# ### Get the values of DataFrame

# %%
train_labels = df_train['label'].tolist()
train_text = df_train['text'].tolist()

test_labels = df_test['label'].tolist()
test_text = df_test['text'].tolist()

assert len(train_labels) == len(train_text)
assert len(test_labels) == len(test_text)

print("len(train_text) = {}, len(test_text) = {}".format(len(train_text), len(test_text)))
# Out:
# len(train_text) = 14277, len(test_text) = 3755

# %%
def unique(list1):
 
    # initialize a null list
    unique_list = []
 
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    # print list
    for x in unique_list:
        print (x)

# %%
unique(train_labels)
# Out:
# fake
# real

# %% [markdown]
# ### Get values indices

# %%
def format_label_value(labels):
    """
    Formats a list of labels to corresponding numeric values.
    """
    format_label_list = []

    for label in labels:
        if label == "fake":
            format_label_list.append(0)
        elif label == "real":
            format_label_list.append(1)
        
    
    return format_label_list

# %%
train_labels = format_label_value(train_labels)
test_labels = format_label_value(test_labels)

# %%
len(train_labels)
# Out:
# 14277

# %% [markdown]
# ## DistilBert Tokenization & Input Formatting

# %% [markdown]
# ### DistilBert Tokenization

# %%
from transformers import DistilBertTokenizer

# Load the BERT tokenizer.
print('Loading DistilBERT tokenizer...')
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
# Out:
# Loading DistilBERT tokenizer...
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]

# %%
# Print the original sentence.
print('Original: ', train_text[0])
print("len(Original) = ", len(train_text[0]))
print("\n")

# Print the sentence split into tokens.
print('Tokenized: ', tokenizer.tokenize(train_text[0]))
print("len(Tokenized) = ", len(tokenizer.tokenize(train_text[0])))
print("\n")

# Print the sentence mapped to token ids.
print('Token IDs: ', tokenizer.convert_tokens_to_ids(tokenizer.tokenize(train_text[0])))
print("len(Token IDs) = ", len(tokenizer.convert_tokens_to_ids(tokenizer.tokenize(train_text[0]))))
print("\n")
# Out:
# Original:  se acuerdan de la pel cula el despu de ana recuerda lo que est pasando con el hurac n sandi http co jqqerpwn
# len(Original) =  108
#
#
# Tokenized:  ['se', 'ac', '##uer', '##dan', 'de', 'la', 'pe', '##l', 'cu', '##la', 'el', 'des', '##pu', 'de', 'ana', 'rec', '##uer', '##da', 'lo', 'que', 'est', 'pas', '##ando', 'con', 'el', 'hu', '##rac', 'n', 'sand', '##i', 'http', 'co', 'j', '##q', '##q', '##er', '##pw', '##n']
# len(Tokenized) =  38
#
#
# Token IDs:  [7367, 9353, 13094, 7847, 2139, 2474, 21877, 2140, 12731, 2721, 3449, 4078, 14289, 2139, 9617, 28667, 13094, 2850, 8840, 10861, 9765, 14674, 28574, 9530, 3449, 15876, 22648, 1050, 5472, 2072, 8299, 2522, 1046, 4160, 4160, 2121, 28400, 2078]
# len(Token IDs) =  38

# %% [markdown]
# ### Input Formatting for DistilBert

# %%
import logging

# Set logger to avoid warning `token indices sequence length is longer than the specified maximum sequence length for this model (1017 > 512)`
logging.getLogger("transformers.tokenization_utils").setLevel(logging.ERROR)


def text_to_id(tokenizer, text_list):
    """
    It is a function to transform text to id.
    # `encode` will:
    #   (1) Tokenize the sentence.
    #   (2) Prepend the `[CLS]` token to the start.
    #   (3) Append the `[SEP]` token to the end.
    #   (4) Map tokens to their IDs.
    """
    ids_list = []
    
    for item in text_list:
        # Sentence to id and add [CLS] and [SEP]
        encoded_item = tokenizer.encode(item, add_special_tokens=True)
        ids_list.append(encoded_item)
    
    return ids_list

# %%
train_text_ids = text_to_id(tokenizer, train_text)
test_text_ids = text_to_id(tokenizer, test_text)


# Print sentence 0, now as a list of IDs.
print('Original: {}\n'.format(train_text[0]))
print('Token IDs: {}\n'.format(train_text_ids[0]))
print("len(train_text_ids) = {}\n".format(len(train_text_ids)))
print("len(test_text_ids) = {}".format(len(test_text_ids)))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (764 > 512). Running this sequence through the model will result in indexing errors
# Original: se acuerdan de la pel cula el despu de ana recuerda lo que est pasando con el hurac n sandi http co jqqerpwn
#
# Token IDs: [101, 7367, 9353, 13094, 7847, 2139, 2474, 21877, 2140, 12731, 2721, 3449, 4078, 14289, 2139, 9617, 28667, 13094, 2850, 8840, 10861, 9765, 14674, 28574, 9530, 3449, 15876, 22648, 1050, 5472, 2072, 8299, 2522, 1046, 4160, 4160, 2121, 28400, 2078, 102]
#
# len(train_text_ids) = 14277
#
# len(test_text_ids) = 3755

# %%
print('Train: max sentence length: ', max([len(sen) for sen in train_text_ids]))
print('Train: Min sentence length: ', min([len(sen) for sen in train_text_ids]))
print('Test: max sentence length: ', max([len(sen) for sen in test_text_ids]))
print('Test: Min sentence length: ', min([len(sen) for sen in test_text_ids]))
# Out:
# Train: max sentence length:  1161
# Train: Min sentence length:  8
# Test: max sentence length:  399
# Test: Min sentence length:  6

# %% [markdown]
# ### Padding & Truncating

# %%
def padding_truncating(input_ids_list, max_length):
    """
    It is a function to perform padding and truncating
    @param input_ids_list: <List> text_ids
    @param max_length: <Integer> the number we wanna the sentence to be padding or truncating
    @return: processed input_ids_list
    """
    processed_input_ids_list = []
    for item in input_ids_list:
        seq_list = []
        
        if len(item) < max_length:
            # Define a seq_list with the length of max_length
            seq_list = [0] * (max_length - len(item))
            item = item + seq_list
        
        elif len(item) >= max_length:
            item = item[:max_length]
            
        processed_input_ids_list.append(item)
    
    return processed_input_ids_list

# %%
train_padding_list = padding_truncating(train_text_ids, max_length=50)
test_padding_list = padding_truncating(test_text_ids, max_length=50)

# %% [markdown]
# ### Attention Masks

# %%
def get_attention_masks(pad_input_ids_list):
    """
    It is a function to get attention masks:
    
    - If a token ID is 0, then it's padding, set the mask to 0.
    - If a token ID is > 0, then it's a real token, set the mask to 1.
    """
    attention_masks_list = []
    
    for item in pad_input_ids_list:
        
        mask_list = []
        for subitem in item:
            if subitem > 0:
                mask_list.append(1)
            else:
                mask_list.append(0)
        attention_masks_list.append(mask_list)
    
    return attention_masks_list

# %%
train_attention_masks = get_attention_masks(train_padding_list)
test_attention_masks = get_attention_masks(test_padding_list)

assert len(train_text) == len(train_labels) == len(train_attention_masks) == len(train_padding_list), "Training data length mismatch"
assert len(test_text) == len(test_labels) == len(test_attention_masks) == len(test_padding_list), "Testing data length mismatch"

# %%
print(len(train_text), len(train_labels), len(train_attention_masks), len(train_padding_list))
# Out:
# 14277 14277 14277 14277

# %% [markdown]
# ### Split train dataset into train_dataset and validation_dataset

# %%
from sklearn.model_selection import train_test_split

# Use 90% for training and 10% for validation.
train_padding_list, validation_padding_list, train_labels, validation_labels, train_attention_masks, validation_attention_masks = train_test_split(train_padding_list, train_labels, train_attention_masks, random_state=2020, test_size=0.1)

# %%
assert len(train_labels) == len(train_attention_masks) == len(train_padding_list)
assert len(validation_labels) == len(validation_attention_masks) == len(validation_padding_list)
assert len(test_labels) == len(test_attention_masks) == len(test_padding_list)

# %%
print("len(train_labels) = {}\nlen(validation_labels) = {}\nlen(test_labels) = {}".format(len(train_labels), len(validation_labels), len(test_labels)))
# Out:
# len(train_labels) = 12849
# len(validation_labels) = 1428
# len(test_labels) = 3755

# %% [markdown]
# ### Convert to Dataset

# %% [markdown]
# Convert all the List objects to tensor

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# Convert all inputs and labels into torch tensors, the required datatype for our model.
train_inputs = torch.tensor(train_padding_list)
validation_inputs = torch.tensor(validation_padding_list)
test_inputs = torch.tensor(test_padding_list)

train_labels = torch.tensor(train_labels)
validation_labels = torch.tensor(validation_labels)
test_labels = torch.tensor(test_labels)

train_masks = torch.tensor(train_attention_masks)
validation_masks = torch.tensor(validation_attention_masks)
test_masks = torch.tensor(test_attention_masks)

# %% [markdown]
# Form the Dataset with torch.tensor

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

# The DataLoader needs to know our batch size for training, so we specify it 
# here.
# For fine-tuning BERT on a specific task, the authors recommend a batch size of 16 or 32.

batch_size = 16

# Create the DataLoader for our training set.
train_data = TensorDataset(train_inputs, train_masks, train_labels)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

# Create the DataLoader for our validation set.
validation_data = TensorDataset(validation_inputs, validation_masks, validation_labels)
validation_sampler = RandomSampler(validation_data)
validation_dataloader = DataLoader(validation_data, sampler=validation_sampler, batch_size=batch_size)

# Create the DataLoader for our test set.
test_data = TensorDataset(test_inputs, test_masks, test_labels)
test_sampler = SequentialSampler(test_data)
test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_size)

# %% [markdown]
# ## Train DistilBert Text Classification Model

# %%
from transformers import DistilBertForSequenceClassification, AdamW, BertConfig
import torch

# Load BertForSequenceClassification, the pretrained BERT model
model = DistilBertForSequenceClassification.from_pretrained(
    "distilbert-base-uncased",  # Use the 12-layer BERT model, with an uncased vocab.
     num_labels = 2,      # The number of output labels -- 2 for binary classification.
                    # You can increase this for multi-class tasks.   
     output_attentions = False, # Whether the model returns attentions weights.
     output_hidden_states = False, # Whether the model returns all hidden-states.
)

model.to(device)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.bias', 'vocab_projector.weight', 'vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'classifier.bias', 'pre_classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (1): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (2): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (3): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (4): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (5): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# ### Optimizer & Learning Rate Scheduler

# %%
# Note: AdamW is a class from the huggingface library (as opposed to pytorch) 
# I believe the 'W' stands for 'Weight Decay fix"
optimizer = AdamW(model.parameters(),
                  lr = 5e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
from transformers import get_linear_schedule_with_warmup

# Number of training epochs (authors recommend between 2 and 4)
epochs = 4

# Total number of training steps is number of batches * number of epochs.
total_steps = len(train_dataloader) * epochs
print("total_steps = {}".format(total_steps))

# Create the learning rate scheduler.
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0, # Default value in run_glue.py
                                            num_training_steps = total_steps)
# Out:
# total_steps = 3216

# %% [markdown]
# ### Train

# %%
import numpy as np

# Function to calculate the accuracy of our predictions vs labels
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
import time
import datetime

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import random

# Set the seed value all over the place to make this reproducible.
seed_val = 12345

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)

# Store the average loss after each epoch so we can plot them.
loss_values = []

# For each epoch...
for epoch_i in range(epochs):
    
    ##########################################
    #               Training                 #
    ##########################################
    
    # Perform one full pass over the training set.

    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    # Measure how long the training epoch takes.
    t0 = time.time()

    # Reset the total loss for this epoch.
    total_loss = 0

    # Put the model into training mode. Don't be mislead--the call to 
    # `train` just changes the *mode*, it doesn't *perform* the training.
    # `dropout` and `batchnorm` layers behave differently during training
    # vs. test (source: https://stackoverflow.com/questions/51433378/what-does-model-train-do-in-pytorch)
    model.train()

    # For each batch of training data...
    for step, batch in enumerate(train_dataloader):

        # Progress update every 10 batches.
        if step % 10 == 0 and not step == 0:
            # Calculate elapsed time in minutes.
            elapsed = format_time(time.time() - t0)
            
            # Report progress.
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))

        # Unpack this training batch from our dataloader. 
        # `batch` contains three pytorch tensors:
        #   [0]: input ids 
        #   [1]: attention masks
        #   [2]: labels 
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        # Clear the gradients.
        model.zero_grad()        

        # Perform a forward pass (evaluate the model on this training batch).
        # This will return the loss (rather than the model output) because we have provided the `labels`.
        outputs = model(b_input_ids, 
                        
                        attention_mask=b_input_mask, 
                        labels=b_labels)
        
        # The call to `model` always returns a tuple, so we need to pull the 
        # loss value out of the tuple.
        loss = outputs[0]

        # Accumulate the training loss over all of the batches so that we can calculate the average loss at the end. 
        # `loss` is a Tensor containing a single value; the `.item()` function just returns the Python value from the tensor.
        total_loss += loss.item()

        # Perform a `backward` pass to calculate the gradients.
        loss.backward()

        # Clip the norm of the gradients to 1.0.
        # This is to help prevent the "exploding gradients" problem.
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # Update parameters and take a step using the computed gradient.
        # The optimizer dictates the "update rule"--how the parameters are modified based on their gradients, the learning rate, etc.
        optimizer.step()

        # Update the learning rate.
        scheduler.step()

    # Calculate the average loss over the training data.
    avg_train_loss = total_loss / len(train_dataloader)            
    
    # Store the loss value for plotting the learning curve.
    loss_values.append(avg_train_loss)

    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epcoh took: {:}".format(format_time(time.time() - t0)))
        
        
    ##########################################
    #               Validation               #
    ##########################################
    # After the completion of each training epoch, measure our performance on our validation set.

    print("")
    print("Running Validation...")

    t0 = time.time()

    # Put the model in evaluation mode--the dropout layers behave differently during evaluation.
    model.eval()

    # Tracking variables 
    eval_loss, eval_accuracy = 0, 0
    nb_eval_steps, nb_eval_examples = 0, 0

    # Evaluate data for one epoch
    for batch in validation_dataloader:
        
        # Add batch to device
        batch = tuple(t.to(device) for t in batch)
        
        # Unpack the inputs from our dataloader
        b_input_ids, b_input_mask, b_labels = batch
        
        # Telling the model not to compute or store gradients, saving memory and speeding up validation
        with torch.no_grad():        

            # Forward pass, calculate logit predictions.
            # This will return the logits rather than the loss because we have not provided labels.
            # token_type_ids is the same as the "segment ids", which differentiates sentence 1 and 2 in 2-sentence tasks.
            # The documentation for this `model` function is here: 
            # https://huggingface.co/transformers/v2.2.0/model_doc/bert.html#transformers.BertForSequenceClassification
            outputs = model(b_input_ids, 
                            
                            attention_mask=b_input_mask)
        
        # Get the "logits" output by the model. The "logits" are the output
        # values prior to applying an activation function like the softmax.
        logits = outputs[0]

        # Move logits and labels to CPU
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        
        # Calculate the accuracy for this batch of test sentences.
        # flat_accuracy(y_pred, y_true)
        tmp_eval_accuracy = flat_accuracy(logits, label_ids)
        
        # Accumulate the total accuracy.
        eval_accuracy += tmp_eval_accuracy

        # Track the number of batches
        nb_eval_steps += 1

    # Report the final accuracy for this validation run.
    print("  Accuracy: {0:.2f}".format(eval_accuracy/nb_eval_steps))
#   Batch   290  of    804.    Elapsed: 0:00:25.
#   Batch   300  of    804.    Elapsed: 0:00:26.
#   Batch   310  of    804.    Elapsed: 0:00:27.
#   Batch   320  of    804.    Elapsed: 0:00:28.
#   Batch   330  of    804.    Elapsed: 0:00:29.
#   Batch   340  of    804.    Elapsed: 0:00:30.
#   Batch   350  of    804.    Elapsed: 0:00:31.
#   Batch   360  of    804.    Elapsed: 0:00:31.
#   Batch   370  of    804.    Elapsed: 0:00:32.
#   Batch   380  of    804.    Elapsed: 0:00:33.
#   Batch   390  of    804.    Elapsed: 0:00:34.
#   Batch   400  of    804.    Elapsed: 0:00:35.
#   Batch   410  of    804.    Elapsed: 0:00:36.
#   Batch   420  of    804.    Elapsed: 0:00:37.
#   Batch   430  of    804.    Elapsed: 0:00:38.
#   Batch   440  of    804.    Elapsed: 0:00:38.
#   Batch   450  of    804.    Elapsed: 0:00:39.
#   Batch   460  of    804.    Elapsed: 0:00:40.
#   Batch   470  of    804.    Elapsed: 0:00:41.
#   Batch   480  of    804.    Elapsed: 0:00:42.
#   Batch   490  of    804.    Elapsed: 0:00:43.
#   Batch   500  of    804.    Elapsed: 0:00:44.
#   Batch   510  of    804.    Elapsed: 0:00:45.
#   Batch   520  of    804.    Elapsed: 0:00:45.
#   Batch   530  of    804.    Elapsed: 0:00:46.
#   Batch   540  of    804.    Elapsed: 0:00:47.
#   Batch   550  of    804.    Elapsed: 0:00:48.
#   Batch   560  of    804.    Elapsed: 0:00:49.
#   Batch   570  of    804.    Elapsed: 0:00:50.
#   Batch   580  of    804.    Elapsed: 0:00:51.
#   Batch   590  of    804.    Elapsed: 0:00:52.
#   Batch   600  of    804.    Elapsed: 0:00:52.
#   Batch   610  of    804.    Elapsed: 0:00:53.
#   Batch   620  of    804.    Elapsed: 0:00:54.
#   Batch   630  of    804.    Elapsed: 0:00:55.
#   Batch   640  of    804.    Elapsed: 0:00:56.
#   Batch   650  of    804.    Elapsed: 0:00:57.
#   Batch   660  of    804.    Elapsed: 0:00:58.
#   Batch   670  of    804.    Elapsed: 0:00:59.
#   Batch   680  of    804.    Elapsed: 0:00:59.
#   Batch   690  of    804.    Elapsed: 0:01:00.
#   Batch   700  of    804.    Elapsed: 0:01:01.
#   Batch   710  of    804.    Elapsed: 0:01:02.
#   Batch   720  of    804.    Elapsed: 0:01:03.
#   Batch   730  of    804.    Elapsed: 0:01:04.
#   Batch   740  of    804.    Elapsed: 0:01:05.
#   Batch   750  of    804.    Elapsed: 0:01:06.
#   Batch   760  of    804.    Elapsed: 0:01:06.
#   Batch   770  of    804.    Elapsed: 0:01:07.
#   Batch   780  of    804.    Elapsed: 0:01:08.
#   Batch   790  of    804.    Elapsed: 0:01:09.
#   Batch   800  of    804.    Elapsed: 0:01:10.
#
#   Average training loss: 0.08
#   Training epcoh took: 0:01:10
#
# Running Validation...
#   Accuracy: 0.91
#   Validation took: 0:00:02
#
# Training complete!

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# Use plot styling from seaborn.
sns.set(style='darkgrid')

# Increase the plot size and font size.
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)

# Plot the learning curve.
plt.plot(loss_values, 'b-o')

# Label the plot.
plt.title("Training loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.show()

# %% [markdown]
# ### Evaluation

# %%
print('Predicting labels for {:,} test sentences...'.format(len(test_inputs)))

# Put model in evaluation mode
model.eval()

# Tracking variables 
predictions, true_labels = [], []

# Predict 
total_correct = 0
for idx, batch in enumerate(test_dataloader):
    
    print("Batch {}".format(idx + 1))
    
    # Add batch to device
    batch = tuple(t.to(device) for t in batch)
  
    # Unpack the inputs from our dataloader
    b_input_ids, b_input_mask, b_labels = batch
  
    # Telling the model not to compute or store gradients, saving memory and 
    # speeding up prediction
    with torch.no_grad():
        # Forward pass, calculate logit predictions
        outputs = model(b_input_ids, 
                        attention_mask=b_input_mask)

    # Get the prediction probability
    logits = outputs[0]
    
    # Get the prediction label
    pred = torch.argmax(logits, dim=1)
   
    # Get the number of correct predictions in this batch
    batch_correct = (pred == b_labels).sum().item()
    print("Batch correct = {}\n".format(batch_correct))
    
    # Accumulate the number of correct predictions over all batches
    total_correct += batch_correct
    
    # Append the predicted labels and true labels for this batch
    predictions.append(pred.cpu().numpy())
    true_labels.append(b_labels.cpu().numpy())
    

print('DONE.')
print("Total correct = ", total_correct)
print("Test accuracy = {0:.2f}".format(total_correct / len(test_inputs)))

# Concatenate the predicted labels and true labels over all batches
predictions = np.concatenate(predictions, axis=0)
true_labels = np.concatenate(true_labels, axis=0)

# Print classification report and confusion matrix
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(true_labels, predictions))
print(confusion_matrix(true_labels, predictions))
# Out:
# Predicting labels for 3,755 test sentences...
# Batch 1
# Batch correct = 5
#
# Batch 2
# Batch correct = 1
#
# Batch 3
# Batch correct = 4
#
# Batch 4
# Batch correct = 4
#
# Batch 5
# Batch correct = 4
#
# Batch 6
# Batch correct = 2
#
# Batch 7
# Batch correct = 5
#
# Batch 8
# Batch correct = 3
#
# Batch 9
# Batch correct = 10
#
# Batch 10
# Batch correct = 16
#
# Batch 11
# Batch correct = 10
#
# Batch 12
# Batch correct = 13
#
# Batch 13
# Batch correct = 14
#
# Batch 14
# Batch correct = 12
#
# Batch 15
# Batch correct = 12
#
# Batch 16
# Batch correct = 14
#
# Batch 17
# Batch correct = 14
#
# Batch 18
# Batch correct = 13
#
# Batch 19
# Batch correct = 16
#
# Batch 20
# Batch correct = 16
#
# Batch 21
# Batch correct = 16
#
# Batch 22
# Batch correct = 16
#
# Batch 23
# Batch correct = 16
#
# Batch 24
# Batch correct = 16
#
# Batch 25
# Batch correct = 16
#
# Batch 26
# Batch correct = 16
#
# Batch 27
# Batch correct = 16
#
# Batch 28
# Batch correct = 16
#
# Batch 29
# Batch correct = 16
#
# Batch 30
# Batch correct = 16
#
# Batch 31
# Batch correct = 16
#
# Batch 32
# Batch correct = 14
#
# Batch 33
# Batch correct = 16
#
# Batch 34
# Batch correct = 15
#
# Batch 35
# Batch correct = 14
#
# Batch 36
# Batch correct = 16
#
# Batch 37
# Batch correct = 11
#
# Batch 38
# Batch correct = 16
#
# Batch 39
# Batch correct = 16
#
# Batch 40
# Batch correct = 14
#
# Batch 41
# Batch correct = 15
#
# Batch 42
# Batch correct = 16
#
# Batch 43
# Batch correct = 16
#
# Batch 44
# Batch correct = 16
#
# Batch 45
# Batch correct = 12
#
# Batch 46
# Batch correct = 16
#
# Batch 47
# Batch correct = 16
#
# Batch 48
# Batch correct = 16
#
# Batch 49
# Batch correct = 16
#
# Batch 50
# Batch correct = 14
#
# Batch 51
# Batch correct = 16
#
# Batch 52
# Batch correct = 16
#
# Batch 53
# Batch correct = 15
#
# Batch 54
# Batch correct = 4
#
# Batch 55
# Batch correct = 0
#
# Batch 56
# Batch correct = 10
#
# Batch 57
# Batch correct = 16
#
# Batch 58
# Batch correct = 5
#
# Batch 59
# Batch correct = 9
#
# Batch 60
# Batch correct = 16
#
# Batch 61
# Batch correct = 16
#
# Batch 62
# Batch correct = 16
#
# Batch 63
# Batch correct = 16
#
# Batch 64
# Batch correct = 16
#
# Batch 65
# Batch correct = 11
#
# Batch 66
# Batch correct = 0
#
# Batch 67
# Batch correct = 3
#
# Batch 68
# Batch correct = 2
#
# Batch 69
# Batch correct = 2
#
# Batch 70
# Batch correct = 2
#
# Batch 71
# Batch correct = 1
#
# Batch 72
# Batch correct = 4
#
# Batch 73
# Batch correct = 16
#
# Batch 74
# Batch correct = 16
#
# Batch 75
# Batch correct = 16
#
# Batch 76
# Batch correct = 15
#
# Batch 77
# Batch correct = 16
#
# Batch 78
# Batch correct = 16
#
# Batch 79
# Batch correct = 16
#
# Batch 80
# Batch correct = 16
#
# Batch 81
# Batch correct = 16
#
# Batch 82
# Batch correct = 16
#
# Batch 83
# Batch correct = 16
#
# Batch 84
# Batch correct = 16
#
# Batch 85
# Batch correct = 16
#
# Batch 86
# Batch correct = 16
#
# Batch 87
# Batch correct = 16
#
# Batch 88
# Batch correct = 16
#
# Batch 89
# Batch correct = 16
#
# Batch 90
# Batch correct = 16
#
# Batch 91
# Batch correct = 16
#
# Batch 92
# Batch correct = 16
#
# Batch 93
# Batch correct = 16
#
# Batch 94
# Batch correct = 16
#
# Batch 95
# Batch correct = 16
#
# Batch 96
# Batch correct = 16
#
# Batch 97
# Batch correct = 16
#
# Batch 98
# Batch correct = 16
#
# Batch 99
# Batch correct = 16
#
# Batch 100
# Batch correct = 16
#
# Batch 101
# Batch correct = 16
#
# Batch 102
# Batch correct = 16
#
# Batch 103
# Batch correct = 16
#
# Batch 104
# Batch correct = 16
#
# Batch 105
# Batch correct = 16
#
# Batch 106
# Batch correct = 16
#
# Batch 107
# Batch correct = 16
#
# Batch 108
# Batch correct = 16
#
# Batch 109
# Batch correct = 16
#
# Batch 110
# Batch correct = 16
#
# Batch 111
# Batch correct = 16
#
# Batch 112
# Batch correct = 16
#
# Batch 113
# Batch correct = 16
#
# Batch 114
# Batch correct = 16
#
# Batch 115
# Batch correct = 16
#
# Batch 116
# Batch correct = 13
#
# Batch 117
# Batch correct = 4
#
# Batch 118
# Batch correct = 8
#
# Batch 119
# Batch correct = 4
#
# Batch 120
# Batch correct = 3
#
# Batch 121
# Batch correct = 7
#
# Batch 122
# Batch correct = 3
#
# Batch 123
# Batch correct = 2
#
# Batch 124
# Batch correct = 7
#
# Batch 125
# Batch correct = 1
#
# Batch 126
# Batch correct = 4
#
# Batch 127
# Batch correct = 3
#
# Batch 128
# Batch correct = 2
#
# Batch 129
# Batch correct = 2
#
# Batch 130
# Batch correct = 2
#
# Batch 131
# Batch correct = 4
#
# Batch 132
# Batch correct = 3
#
# Batch 133
# Batch correct = 2
#
# Batch 134
# Batch correct = 1
#
# Batch 135
# Batch correct = 2
#
# Batch 136
# Batch correct = 4
#
# Batch 137
# Batch correct = 8
#
# Batch 138
# Batch correct = 5
#
# Batch 139
# Batch correct = 3
#
# Batch 140
# Batch correct = 7
#
# Batch 141
# Batch correct = 6
#
# Batch 142
# Batch correct = 3
#
# Batch 143
# Batch correct = 4
#
# Batch 144
# Batch correct = 4
#
# Batch 145
# Batch correct = 5
#
# Batch 146
# Batch correct = 5
#
# Batch 147
# Batch correct = 4
#
# Batch 148
# Batch correct = 3
#
# Batch 149
# Batch correct = 5
#
# Batch 150
# Batch correct = 4
#
# Batch 151
# Batch correct = 4
#
# Batch 152
# Batch correct = 3
#
# Batch 153
# Batch correct = 4
#
# Batch 154
# Batch correct = 8
#
# Batch 155
# Batch correct = 4
#
# Batch 156
# Batch correct = 15
#
# Batch 157
# Batch correct = 16
#
# Batch 158
# Batch correct = 16
#
# Batch 159
# Batch correct = 16
#
# Batch 160
# Batch correct = 16
#
# Batch 161
# Batch correct = 16
#
# Batch 162
# Batch correct = 16
#
# Batch 163
# Batch correct = 16
#
# Batch 164
# Batch correct = 16
#
# Batch 165
# Batch correct = 16
#
# Batch 166
# Batch correct = 16
#
# Batch 167
# Batch correct = 16
#
# Batch 168
# Batch correct = 5
#
# Batch 169
# Batch correct = 0
#
# Batch 170
# Batch correct = 2
#
# Batch 171
# Batch correct = 1
#
# Batch 172
# Batch correct = 3
#
# Batch 173
# Batch correct = 10
#
# Batch 174
# Batch correct = 8
#
# Batch 175
# Batch correct = 7
#
# Batch 176
# Batch correct = 10
#
# Batch 177
# Batch correct = 8
#
# Batch 178
# Batch correct = 8
#
# Batch 179
# Batch correct = 6
#
# Batch 180
# Batch correct = 9
#
# Batch 181
# Batch correct = 6
#
# Batch 182
# Batch correct = 4
#
# Batch 183
# Batch correct = 2
#
# Batch 184
# Batch correct = 3
#
# Batch 185
# Batch correct = 10
#
# Batch 186
# Batch correct = 16
#
# Batch 187
# Batch correct = 16
#
# Batch 188
# Batch correct = 16
#
# Batch 189
# Batch correct = 16
#
# Batch 190
# Batch correct = 16
#
# Batch 191
# Batch correct = 16
#
# Batch 192
# Batch correct = 16
#
# Batch 193
# Batch correct = 16
#
# Batch 194
# Batch correct = 16
#
# Batch 195
# Batch correct = 16
#
# Batch 196
# Batch correct = 14
#
# Batch 197
# Batch correct = 6
#
# Batch 198
# Batch correct = 6
#
# Batch 199
# Batch correct = 6
#
# Batch 200
# Batch correct = 6
#
# Batch 201
# Batch correct = 5
#
# Batch 202
# Batch correct = 3
#
# Batch 203
# Batch correct = 2
#
# Batch 204
# Batch correct = 6
#
# Batch 205
# Batch correct = 1
#
# Batch 206
# Batch correct = 4
#
# Batch 207
# Batch correct = 3
#
# Batch 208
# Batch correct = 5
#
# Batch 209
# Batch correct = 5
#
# Batch 210
# Batch correct = 0
#
# Batch 211
# Batch correct = 5
#
# Batch 212
# Batch correct = 5
#
# Batch 213
# Batch correct = 4
#
# Batch 214
# Batch correct = 4
#
# Batch 215
# Batch correct = 3
#
# Batch 216
# Batch correct = 3
#
# Batch 217
# Batch correct = 5
#
# Batch 218
# Batch correct = 2
#
# Batch 219
# Batch correct = 2
#
# Batch 220
# Batch correct = 1
#
# Batch 221
# Batch correct = 1
#
# Batch 222
# Batch correct = 0
#
# Batch 223
# Batch correct = 1
#
# Batch 224
# Batch correct = 1
#
# Batch 225
# Batch correct = 3
#
# Batch 226
# Batch correct = 9
#
# Batch 227
# Batch correct = 10
#
# Batch 228
# Batch correct = 7
#
# Batch 229
# Batch correct = 5
#
# Batch 230
# Batch correct = 8
#
# Batch 231
# Batch correct = 8
#
# Batch 232
# Batch correct = 4
#
# Batch 233
# Batch correct = 8
#
# Batch 234
# Batch correct = 8
#
# Batch 235
# Batch correct = 5
#
# DONE.
# Total correct =  2339
# Test accuracy = 0.62
#               precision    recall  f1-score   support
#
#            0       0.85      0.53      0.66      2546
#            1       0.45      0.81      0.58      1209
#
#     accuracy                           0.62      3755
#    macro avg       0.65      0.67      0.62      3755
# weighted avg       0.72      0.62      0.63      3755
#
# [[1362 1184]
#  [ 232  977]]

# %% [markdown]
# # Twitter 2016

# %% [markdown]
# ## Data Pre-processing

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Read dataset file

# %%
import pandas as pd
import numpy as np

train_filename = "/content/drive/MyDrive/NLP Project/Datasets/Twitter2016/tweetstrain2016.csv"
test_filename = "/content/drive/MyDrive/NLP Project/Datasets/Twitter2016/tweetstest2016.csv"

df_train = pd.read_csv(train_filename)
df_test = pd.read_csv(test_filename)

# %%
df_train.columns.values.tolist()
# Out:
# ['Unnamed: 0.1', 'Unnamed: 0', 'tweetId', 'tweetText', 'label']

# %%
df_train = df_train.drop('Unnamed: 0', axis=1)
df_train = df_train.drop('tweetId', axis=1)

# %%
df_test = df_test.drop('Unnamed: 0', axis=1)
df_test = df_test.drop('tweetId', axis=1)

# %%
df_train = df_train.rename(columns={'tweetText': 'text'})
df_test = df_test.rename(columns={'tweetText': 'text'})

# %%
df_train.head()
# Out:
#    Unnamed: 0.1                                               text label
# 0             0   need fed solv bostonbomb chan http co exqtpzqqbg  fake
# 1             1  pic comparison boston suspect sunil tripathi f...  fake
# 2             2  complet convinc sunil tripathi fellow http co ...  fake
# 3             3  brutal lo que se pued conseguir en colaboraci ...  fake
# 4             4  chan bomb throw http co diyso lxqm http co nxb...  fake

# %%
df_test.head()
# Out:
#    Unnamed: 0.1                                               text label
# 0             0  antiterror arabianblood russianfeder syria dai...  fake
# 1             1                                 n http co ws jxmgj  fake
# 2             2                 http co lz awn nhttp co gvsduzmaxa  fake
# 3             3               http co kg quidotf http co dkfmxppje  fake
# 4             4  nthe airstrik isi ammunit depot near talbiseh ...  fake

# %%
df_train.loc[df_train.label == 'fake'].sample(10)
# Out:
#        Unnamed: 0.1                                               text label
# 3275           3275               hurrican real sandi http co xactwxon  fake
# 1855           1855                          nyc sandi http co koiz zg  fake
# 4225           4225  thetroyreport even statu liberti afraid hurric...  fake
# 1087           1087  rt komalminha well insan imag sandi http co rd...  fake
# 1345           1345  newyork sandi holyshit instapropheci http co w...  fake
# 15559         15559  hero syrian boy risk life rescu girl assad reg...  fake
# 172             172  rt sodagrrl imag bomb suspect http co gebhz nc...  fake
# 166             166  go around boston bomb suspect boston prayforbo...  fake
# 2185           2185                                sandi http co slcsv  fake
# 3210           3210  aar allo shark swim front yard flood home brig...  fake

# %% [markdown]
# ### Get the values of DataFrame

# %%
train_labels = df_train['label'].tolist()
train_text = df_train['text'].tolist()

test_labels = df_test['label'].tolist()
test_text = df_test['text'].tolist()

assert len(train_labels) == len(train_text)
assert len(test_labels) == len(test_text)

print("len(train_text) = {}, len(test_text) = {}".format(len(train_text), len(test_text)))
# Out:
# len(train_text) = 15629, len(test_text) = 2177

# %%
def unique(list1):
 
    # initialize a null list
    unique_list = []
 
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    # print list
    for x in unique_list:
        print (x)

# %%
unique(train_labels)
# Out:
# fake
# real

# %% [markdown]
# ### Get values indices

# %%
def format_label_value(labels):
    """
    Formats a list of labels to corresponding numeric values.
    """
    format_label_list = []

    for label in labels:
        if label == "fake":
            format_label_list.append(0)
        elif label == "real":
            format_label_list.append(1)
        
    
    return format_label_list

# %%
train_labels = format_label_value(train_labels)
test_labels = format_label_value(test_labels)

# %%
len(train_labels)
# Out:
# 15629

# %% [markdown]
# ## DistilBert Tokenization & Input Formatting

# %% [markdown]
# ### DistilBert Tokenization

# %%
from transformers import DistilBertTokenizer

# Load the BERT tokenizer.
print('Loading DistilBERT tokenizer...')
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
# Out:
# Loading DistilBERT tokenizer...

# %%
# Print the original sentence.
print('Original: ', train_text[0])
print("len(Original) = ", len(train_text[0]))
print("\n")

# Print the sentence split into tokens.
print('Tokenized: ', tokenizer.tokenize(train_text[0]))
print("len(Tokenized) = ", len(tokenizer.tokenize(train_text[0])))
print("\n")

# Print the sentence mapped to token ids.
print('Token IDs: ', tokenizer.convert_tokens_to_ids(tokenizer.tokenize(train_text[0])))
print("len(Token IDs) = ", len(tokenizer.convert_tokens_to_ids(tokenizer.tokenize(train_text[0]))))
print("\n")
# Out:
# Original:  need fed solv bostonbomb chan http co exqtpzqqbg
# len(Original) =  48
#
#
# Tokenized:  ['need', 'fed', 'sol', '##v', 'boston', '##bo', '##mb', 'chan', 'http', 'co', 'ex', '##q', '##tp', '##z', '##q', '##q', '##b', '##g']
# len(Tokenized) =  18
#
#
# Token IDs:  [2342, 7349, 14017, 2615, 3731, 5092, 14905, 9212, 8299, 2522, 4654, 4160, 25856, 2480, 4160, 4160, 2497, 2290]
# len(Token IDs) =  18

# %% [markdown]
# ### Input Formatting for DistilBert

# %%
import logging

# Set logger to avoid warning `token indices sequence length is longer than the specified maximum sequence length for this model (1017 > 512)`
logging.getLogger("transformers.tokenization_utils").setLevel(logging.ERROR)


def text_to_id(tokenizer, text_list):
    """
    It is a function to transform text to id.
    # `encode` will:
    #   (1) Tokenize the sentence.
    #   (2) Prepend the `[CLS]` token to the start.
    #   (3) Append the `[SEP]` token to the end.
    #   (4) Map tokens to their IDs.
    """
    ids_list = []
    
    for item in text_list:
        # Sentence to id and add [CLS] and [SEP]
        encoded_item = tokenizer.encode(item, add_special_tokens=True)
        ids_list.append(encoded_item)
    
    return ids_list

# %%
train_text_ids = text_to_id(tokenizer, train_text)
test_text_ids = text_to_id(tokenizer, test_text)


# Print sentence 0, now as a list of IDs.
print('Original: {}\n'.format(train_text[0]))
print('Token IDs: {}\n'.format(train_text_ids[0]))
print("len(train_text_ids) = {}\n".format(len(train_text_ids)))
print("len(test_text_ids) = {}".format(len(test_text_ids)))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (948 > 512). Running this sequence through the model will result in indexing errors
# Original: need fed solv bostonbomb chan http co exqtpzqqbg
#
# Token IDs: [101, 2342, 7349, 14017, 2615, 3731, 5092, 14905, 9212, 8299, 2522, 4654, 4160, 25856, 2480, 4160, 4160, 2497, 2290, 102]
#
# len(train_text_ids) = 15629
#
# len(test_text_ids) = 2177

# %%
print('Train: max sentence length: ', max([len(sen) for sen in train_text_ids]))
print('Train: Min sentence length: ', min([len(sen) for sen in train_text_ids]))
print('Test: max sentence length: ', max([len(sen) for sen in test_text_ids]))
print('Test: Min sentence length: ', min([len(sen) for sen in test_text_ids]))
# Out:
# Train: max sentence length:  53
# Train: Min sentence length:  6
# Test: max sentence length:  948
# Test: Min sentence length:  7

# %% [markdown]
# ### Padding & Truncating

# %%
def padding_truncating(input_ids_list, max_length):
    """
    It is a function to perform padding and truncating
    @param input_ids_list: <List> text_ids
    @param max_length: <Integer> the number we wanna the sentence to be padding or truncating
    @return: processed input_ids_list
    """
    processed_input_ids_list = []
    for item in input_ids_list:
        seq_list = []
        
        if len(item) < max_length:
            # Define a seq_list with the length of max_length
            seq_list = [0] * (max_length - len(item))
            item = item + seq_list
        
        elif len(item) >= max_length:
            item = item[:max_length]
            
        processed_input_ids_list.append(item)
    
    return processed_input_ids_list

# %%
train_padding_list = padding_truncating(train_text_ids, max_length=50)
test_padding_list = padding_truncating(test_text_ids, max_length=50)

# %% [markdown]
# ### Attention Masks

# %%
def get_attention_masks(pad_input_ids_list):
    """
    It is a function to get attention masks:
    
    - If a token ID is 0, then it's padding, set the mask to 0.
    - If a token ID is > 0, then it's a real token, set the mask to 1.
    """
    attention_masks_list = []
    
    for item in pad_input_ids_list:
        
        mask_list = []
        for subitem in item:
            if subitem > 0:
                mask_list.append(1)
            else:
                mask_list.append(0)
        attention_masks_list.append(mask_list)
    
    return attention_masks_list

# %%
train_attention_masks = get_attention_masks(train_padding_list)
test_attention_masks = get_attention_masks(test_padding_list)

assert len(train_text) == len(train_labels) == len(train_attention_masks) == len(train_padding_list), "Training data length mismatch"
assert len(test_text) == len(test_labels) == len(test_attention_masks) == len(test_padding_list), "Testing data length mismatch"

# %%
print(len(train_text), len(train_labels), len(train_attention_masks), len(train_padding_list))
# Out:
# 15629 15629 15629 15629

# %% [markdown]
# ### Split train dataset into train_dataset and validation_dataset

# %%
from sklearn.model_selection import train_test_split

# Use 90% for training and 10% for validation.
train_padding_list, validation_padding_list, train_labels, validation_labels, train_attention_masks, validation_attention_masks = train_test_split(train_padding_list, train_labels, train_attention_masks, random_state=2020, test_size=0.1)

# %%
assert len(train_labels) == len(train_attention_masks) == len(train_padding_list)
assert len(validation_labels) == len(validation_attention_masks) == len(validation_padding_list)
assert len(test_labels) == len(test_attention_masks) == len(test_padding_list)

# %%
print("len(train_labels) = {}\nlen(validation_labels) = {}\nlen(test_labels) = {}".format(len(train_labels), len(validation_labels), len(test_labels)))
# Out:
# len(train_labels) = 14066
# len(validation_labels) = 1563
# len(test_labels) = 2177

# %% [markdown]
# ### Convert to Dataset

# %% [markdown]
# Convert all the List objects to tensor

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# Convert all inputs and labels into torch tensors, the required datatype for our model.
train_inputs = torch.tensor(train_padding_list)
validation_inputs = torch.tensor(validation_padding_list)
test_inputs = torch.tensor(test_padding_list)

train_labels = torch.tensor(train_labels)
validation_labels = torch.tensor(validation_labels)
test_labels = torch.tensor(test_labels)

train_masks = torch.tensor(train_attention_masks)
validation_masks = torch.tensor(validation_attention_masks)
test_masks = torch.tensor(test_attention_masks)

# %% [markdown]
# Form the Dataset with torch.tensor

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

# The DataLoader needs to know our batch size for training, so we specify it 
# here.
# For fine-tuning BERT on a specific task, the authors recommend a batch size of 16 or 32.

batch_size = 16

# Create the DataLoader for our training set.
train_data = TensorDataset(train_inputs, train_masks, train_labels)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

# Create the DataLoader for our validation set.
validation_data = TensorDataset(validation_inputs, validation_masks, validation_labels)
validation_sampler = RandomSampler(validation_data)
validation_dataloader = DataLoader(validation_data, sampler=validation_sampler, batch_size=batch_size)

# Create the DataLoader for our test set.
test_data = TensorDataset(test_inputs, test_masks, test_labels)
test_sampler = SequentialSampler(test_data)
test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_size)

# %% [markdown]
# ## Train DistilBert Text Classification Model

# %%
from transformers import DistilBertForSequenceClassification, AdamW, BertConfig
import torch

# Load BertForSequenceClassification, the pretrained BERT model
model = DistilBertForSequenceClassification.from_pretrained(
    "distilbert-base-uncased",  # Use the 12-layer BERT model, with an uncased vocab.
     num_labels = 2,      # The number of output labels -- 2 for binary classification.
                    # You can increase this for multi-class tasks.   
     output_attentions = False, # Whether the model returns attentions weights.
     output_hidden_states = False, # Whether the model returns all hidden-states.
)

model.to(device)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.bias', 'vocab_projector.weight', 'vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'classifier.bias', 'pre_classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (1): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (2): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (3): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (4): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (5): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# ### Optimizer & Learning Rate Scheduler

# %%
# Note: AdamW is a class from the huggingface library (as opposed to pytorch) 
# I believe the 'W' stands for 'Weight Decay fix"
optimizer = AdamW(model.parameters(),
                  lr = 5e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
from transformers import get_linear_schedule_with_warmup

# Number of training epochs (authors recommend between 2 and 4)
epochs = 4

# Total number of training steps is number of batches * number of epochs.
total_steps = len(train_dataloader) * epochs
print("total_steps = {}".format(total_steps))

# Create the learning rate scheduler.
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0, # Default value in run_glue.py
                                            num_training_steps = total_steps)
# Out:
# total_steps = 3520

# %% [markdown]
# ### Train

# %%
import numpy as np

# Function to calculate the accuracy of our predictions vs labels
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
import time
import datetime

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import random

# Set the seed value all over the place to make this reproducible.
seed_val = 12345

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)

# Store the average loss after each epoch so we can plot them.
loss_values = []

# For each epoch...
for epoch_i in range(epochs):
    
    ##########################################
    #               Training                 #
    ##########################################
    
    # Perform one full pass over the training set.

    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    # Measure how long the training epoch takes.
    t0 = time.time()

    # Reset the total loss for this epoch.
    total_loss = 0

    # Put the model into training mode. Don't be mislead--the call to 
    # `train` just changes the *mode*, it doesn't *perform* the training.
    # `dropout` and `batchnorm` layers behave differently during training
    # vs. test (source: https://stackoverflow.com/questions/51433378/what-does-model-train-do-in-pytorch)
    model.train()

    # For each batch of training data...
    for step, batch in enumerate(train_dataloader):

        # Progress update every 10 batches.
        if step % 10 == 0 and not step == 0:
            # Calculate elapsed time in minutes.
            elapsed = format_time(time.time() - t0)
            
            # Report progress.
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))

        # Unpack this training batch from our dataloader. 
        # `batch` contains three pytorch tensors:
        #   [0]: input ids 
        #   [1]: attention masks
        #   [2]: labels 
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        # Clear the gradients.
        model.zero_grad()        

        # Perform a forward pass (evaluate the model on this training batch).
        # This will return the loss (rather than the model output) because we have provided the `labels`.
        outputs = model(b_input_ids, 
                     
                        attention_mask=b_input_mask, 
                        labels=b_labels)
        
        # The call to `model` always returns a tuple, so we need to pull the 
        # loss value out of the tuple.
        loss = outputs[0]

        # Accumulate the training loss over all of the batches so that we can calculate the average loss at the end. 
        # `loss` is a Tensor containing a single value; the `.item()` function just returns the Python value from the tensor.
        total_loss += loss.item()

        # Perform a `backward` pass to calculate the gradients.
        loss.backward()

        # Clip the norm of the gradients to 1.0.
        # This is to help prevent the "exploding gradients" problem.
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # Update parameters and take a step using the computed gradient.
        # The optimizer dictates the "update rule"--how the parameters are modified based on their gradients, the learning rate, etc.
        optimizer.step()

        # Update the learning rate.
        scheduler.step()

    # Calculate the average loss over the training data.
    avg_train_loss = total_loss / len(train_dataloader)            
    
    # Store the loss value for plotting the learning curve.
    loss_values.append(avg_train_loss)

    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epcoh took: {:}".format(format_time(time.time() - t0)))
        
        
    ##########################################
    #               Validation               #
    ##########################################
    # After the completion of each training epoch, measure our performance on our validation set.

    print("")
    print("Running Validation...")

    t0 = time.time()

    # Put the model in evaluation mode--the dropout layers behave differently during evaluation.
    model.eval()

    # Tracking variables 
    eval_loss, eval_accuracy = 0, 0
    nb_eval_steps, nb_eval_examples = 0, 0

    # Evaluate data for one epoch
    for batch in validation_dataloader:
        
        # Add batch to device
        batch = tuple(t.to(device) for t in batch)
        
        # Unpack the inputs from our dataloader
        b_input_ids, b_input_mask, b_labels = batch
        
        # Telling the model not to compute or store gradients, saving memory and speeding up validation
        with torch.no_grad():        

            # Forward pass, calculate logit predictions.
            # This will return the logits rather than the loss because we have not provided labels.
            # token_type_ids is the same as the "segment ids", which differentiates sentence 1 and 2 in 2-sentence tasks.
            # The documentation for this `model` function is here: 
            # https://huggingface.co/transformers/v2.2.0/model_doc/bert.html#transformers.BertForSequenceClassification
            outputs = model(b_input_ids, 
                            
                            attention_mask=b_input_mask)
        
        # Get the "logits" output by the model. The "logits" are the output
        # values prior to applying an activation function like the softmax.
        logits = outputs[0]

        # Move logits and labels to CPU
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        
        # Calculate the accuracy for this batch of test sentences.
        # flat_accuracy(y_pred, y_true)
        tmp_eval_accuracy = flat_accuracy(logits, label_ids)
        
        # Accumulate the total accuracy.
        eval_accuracy += tmp_eval_accuracy

        # Track the number of batches
        nb_eval_steps += 1

    # Report the final accuracy for this validation run.
    print("  Accuracy: {0:.2f}".format(eval_accuracy/nb_eval_steps))
    print("  Validation took: {:}".format(format_time(time.time() - t0)))

print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 4 ========
# Training...
#   Batch    10  of    880.    Elapsed: 0:00:01.
#   Batch    20  of    880.    Elapsed: 0:00:02.
#   Batch    30  of    880.    Elapsed: 0:00:03.
#   Batch    40  of    880.    Elapsed: 0:00:04.
#   Batch    50  of    880.    Elapsed: 0:00:04.
#   Batch    60  of    880.    Elapsed: 0:00:05.
#   Batch    70  of    880.    Elapsed: 0:00:06.
#   Batch    80  of    880.    Elapsed: 0:00:07.
#   Batch    90  of    880.    Elapsed: 0:00:08.
#   Batch   100  of    880.    Elapsed: 0:00:09.
#   Batch   110  of    880.    Elapsed: 0:00:10.
#   Batch   120  of    880.    Elapsed: 0:00:11.
#   Batch   130  of    880.    Elapsed: 0:00:12.
#   Batch   140  of    880.    Elapsed: 0:00:12.
#   Batch   150  of    880.    Elapsed: 0:00:13.
#   Batch   160  of    880.    Elapsed: 0:00:14.
#   Batch   170  of    880.    Elapsed: 0:00:15.
#   Batch   180  of    880.    Elapsed: 0:00:16.
#   Batch   190  of    880.    Elapsed: 0:00:17.
#   Batch   200  of    880.    Elapsed: 0:00:18.
#   Batch   210  of    880.    Elapsed: 0:00:19.
#   Batch   220  of    880.    Elapsed: 0:00:20.
#   Batch   230  of    880.    Elapsed: 0:00:21.
#   Batch   240  of    880.    Elapsed: 0:00:22.
#   Batch   250  of    880.    Elapsed: 0:00:22.
#   Batch   260  of    880.    Elapsed: 0:00:23.
#   Batch   270  of    880.    Elapsed: 0:00:24.
#   Batch   280  of    880.    Elapsed: 0:00:25.
#   Batch   290  of    880.    Elapsed: 0:00:26.
#   Batch   300  of    880.    Elapsed: 0:00:27.
#   Batch   310  of    880.    Elapsed: 0:00:28.
#   Batch   320  of    880.    Elapsed: 0:00:29.
#   Batch   330  of    880.    Elapsed: 0:00:30.
#   Batch   340  of    880.    Elapsed: 0:00:31.
#   Batch   350  of    880.    Elapsed: 0:00:32.
#   Batch   360  of    880.    Elapsed: 0:00:33.
#   Batch   370  of    880.    Elapsed: 0:00:33.
#   Batch   380  of    880.    Elapsed: 0:00:34.
#   Batch   390  of    880.    Elapsed: 0:00:35.
#   Batch   400  of    880.    Elapsed: 0:00:36.
#   Batch   410  of    880.    Elapsed: 0:00:37.
#   Batch   420  of    880.    Elapsed: 0:00:38.
#   Batch   430  of    880.    Elapsed: 0:00:39.
#   Batch   440  of    880.    Elapsed: 0:00:40.
#   Batch   450  of    880.    Elapsed: 0:00:41.
#   Batch   460  of    880.    Elapsed: 0:00:41.
#   Batch   470  of    880.    Elapsed: 0:00:42.
#   Batch   480  of    880.    Elapsed: 0:00:43.
#   Batch   590  of    880.    Elapsed: 0:00:52.
#   Batch   600  of    880.    Elapsed: 0:00:53.
#   Batch   610  of    880.    Elapsed: 0:00:53.
#   Batch   620  of    880.    Elapsed: 0:00:54.
#   Batch   630  of    880.    Elapsed: 0:00:55.
#   Batch   640  of    880.    Elapsed: 0:00:56.
#   Batch   650  of    880.    Elapsed: 0:00:57.
#   Batch   660  of    880.    Elapsed: 0:00:58.
#   Batch   670  of    880.    Elapsed: 0:00:59.
#   Batch   680  of    880.    Elapsed: 0:01:00.
#   Batch   690  of    880.    Elapsed: 0:01:00.
#   Batch   700  of    880.    Elapsed: 0:01:01.
#   Batch   710  of    880.    Elapsed: 0:01:02.
#   Batch   720  of    880.    Elapsed: 0:01:03.
#   Batch   730  of    880.    Elapsed: 0:01:04.
#   Batch   740  of    880.    Elapsed: 0:01:05.
#   Batch   750  of    880.    Elapsed: 0:01:06.
#   Batch   760  of    880.    Elapsed: 0:01:07.
#   Batch   770  of    880.    Elapsed: 0:01:07.
#   Batch   780  of    880.    Elapsed: 0:01:08.
#   Batch   790  of    880.    Elapsed: 0:01:09.
#   Batch   800  of    880.    Elapsed: 0:01:10.
#   Batch   810  of    880.    Elapsed: 0:01:11.
#   Batch   820  of    880.    Elapsed: 0:01:12.
#   Batch   830  of    880.    Elapsed: 0:01:13.
#   Batch   840  of    880.    Elapsed: 0:01:14.
#   Batch   850  of    880.    Elapsed: 0:01:14.
#   Batch   860  of    880.    Elapsed: 0:01:15.
#   Batch   870  of    880.    Elapsed: 0:01:16.
#
#   Average training loss: 0.07
#   Training epcoh took: 0:01:17
#
# Running Validation...
#   Accuracy: 0.92
#   Validation took: 0:00:03
#
# Training complete!

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# Use plot styling from seaborn.
sns.set(style='darkgrid')

# Increase the plot size and font size.
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)

# Plot the learning curve.
plt.plot(loss_values, 'b-o')

# Label the plot.
plt.title("Training loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.show()

# %% [markdown]
# ### Evaluation

# %%
print('Predicting labels for {:,} test sentences...'.format(len(test_inputs)))

# Put model in evaluation mode
model.eval()

# Tracking variables 
predictions, true_labels = [], []

# Predict 
total_correct = 0
for idx, batch in enumerate(test_dataloader):
    
    print("Batch {}".format(idx + 1))
    
    # Add batch to device
    batch = tuple(t.to(device) for t in batch)
  
    # Unpack the inputs from our dataloader
    b_input_ids, b_input_mask, b_labels = batch
  
    # Telling the model not to compute or store gradients, saving memory and 
    # speeding up prediction
    with torch.no_grad():
        # Forward pass, calculate logit predictions
        outputs = model(b_input_ids, 
                        attention_mask=b_input_mask)

    # Get the prediction probability
    logits = outputs[0]
    
    # Get the prediction label
    pred = torch.argmax(logits, dim=1)
   
    # Get the number of correct predictions in this batch
    batch_correct = (pred == b_labels).sum().item()
    print("Batch correct = {}\n".format(batch_correct))
    
    # Accumulate the number of correct predictions over all batches
    total_correct += batch_correct
    
    # Append the predicted labels and true labels for this batch
    predictions.append(pred.cpu().numpy())
    true_labels.append(b_labels.cpu().numpy())
    

print('DONE.')
print("Total correct = ", total_correct)
print("Test accuracy = {0:.2f}".format(total_correct / len(test_inputs)))

# Concatenate the predicted labels and true labels over all batches
predictions = np.concatenate(predictions, axis=0)
true_labels = np.concatenate(true_labels, axis=0)

# Print classification report and confusion matrix
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(true_labels, predictions))
print(confusion_matrix(true_labels, predictions))
# Out:
# Predicting labels for 2,177 test sentences...
# Batch 1
# Batch correct = 9
#
# Batch 2
# Batch correct = 12
#
# Batch 3
# Batch correct = 7
#
# Batch 4
# Batch correct = 3
#
# Batch 5
# Batch correct = 6
#
# Batch 6
# Batch correct = 2
#
# Batch 7
# Batch correct = 4
#
# Batch 8
# Batch correct = 14
#
# Batch 9
# Batch correct = 3
#
# Batch 10
# Batch correct = 12
#
# Batch 11
# Batch correct = 12
#
# Batch 12
# Batch correct = 13
#
# Batch 13
# Batch correct = 15
#
# Batch 14
# Batch correct = 13
#
# Batch 15
# Batch correct = 13
#
# Batch 16
# Batch correct = 4
#
# Batch 17
# Batch correct = 0
#
# Batch 18
# Batch correct = 12
#
# Batch 19
# Batch correct = 14
#
# Batch 20
# Batch correct = 8
#
# Batch 21
# Batch correct = 11
#
# Batch 22
# Batch correct = 10
#
# Batch 23
# Batch correct = 8
#
# Batch 24
# Batch correct = 12
#
# Batch 25
# Batch correct = 11
#
# Batch 26
# Batch correct = 8
#
# Batch 27
# Batch correct = 11
#
# Batch 28
# Batch correct = 9
#
# Batch 29
# Batch correct = 9
#
# Batch 30
# Batch correct = 7
#
# Batch 31
# Batch correct = 9
#
# Batch 32
# Batch correct = 9
#
# Batch 33
# Batch correct = 6
#
# Batch 34
# Batch correct = 13
#
# Batch 35
# Batch correct = 15
#
# Batch 36
# Batch correct = 16
#
# Batch 37
# Batch correct = 16
#
# Batch 38
# Batch correct = 16
#
# Batch 39
# Batch correct = 16
#
# Batch 40
# Batch correct = 14
#
# Batch 41
# Batch correct = 15
#
# Batch 42
# Batch correct = 11
#
# Batch 43
# Batch correct = 11
#
# Batch 44
# Batch correct = 7
#
# Batch 45
# Batch correct = 1
#
# Batch 46
# Batch correct = 8
#
# Batch 47
# Batch correct = 12
#
# Batch 48
# Batch correct = 10
#
# Batch 49
# Batch correct = 10
#
# Batch 50
# Batch correct = 11
#
# Batch 51
# Batch correct = 5
#
# Batch 52
# Batch correct = 3
#
# Batch 53
# Batch correct = 3
#
# Batch 54
# Batch correct = 9
#
# Batch 55
# Batch correct = 10
#
# Batch 56
# Batch correct = 11
#
# Batch 57
# Batch correct = 3
#
# Batch 58
# Batch correct = 1
#
# Batch 59
# Batch correct = 3
#
# Batch 60
# Batch correct = 3
#
# Batch 61
# Batch correct = 12
#
# Batch 62
# Batch correct = 13
#
# Batch 63
# Batch correct = 14
#
# Batch 64
# Batch correct = 16
#
# Batch 65
# Batch correct = 10
#
# Batch 66
# Batch correct = 14
#
# Batch 67
# Batch correct = 11
#
# Batch 68
# Batch correct = 10
#
# Batch 69
# Batch correct = 14
#
# Batch 70
# Batch correct = 15
#
# Batch 71
# Batch correct = 12
#
# Batch 72
# Batch correct = 15
#
# Batch 73
# Batch correct = 12
#
# Batch 74
# Batch correct = 13
#
# Batch 75
# Batch correct = 11
#
# Batch 76
# Batch correct = 14
#
# Batch 77
# Batch correct = 11
#
# Batch 78
# Batch correct = 14
#
# Batch 79
# Batch correct = 12
#
# Batch 80
# Batch correct = 5
#
# Batch 81
# Batch correct = 3
#
# Batch 82
# Batch correct = 5
#
# Batch 83
# Batch correct = 8
#
# Batch 84
# Batch correct = 11
#
# Batch 85
# Batch correct = 10
#
# Batch 86
# Batch correct = 8
#
# Batch 87
# Batch correct = 10
#
# Batch 88
# Batch correct = 6
#
# Batch 89
# Batch correct = 7
#
# Batch 90
# Batch correct = 4
#
# Batch 91
# Batch correct = 8
#
# Batch 92
# Batch correct = 10
#
# Batch 93
# Batch correct = 16
#
# Batch 94
# Batch correct = 16
#
# Batch 95
# Batch correct = 5
#
# Batch 96
# Batch correct = 13
#
# Batch 97
# Batch correct = 10
#
# Batch 98
# Batch correct = 9
#
# Batch 99
# Batch correct = 7
#
# Batch 100
# Batch correct = 4
#
# Batch 101
# Batch correct = 13
#
# Batch 102
# Batch correct = 9
#
# Batch 103
# Batch correct = 11
#
# Batch 104
# Batch correct = 7
#
# Batch 105
# Batch correct = 9
#
# Batch 106
# Batch correct = 2
#
# Batch 107
# Batch correct = 1
#
# Batch 108
# Batch correct = 0
#
# Batch 109
# Batch correct = 1
#
# Batch 110
# Batch correct = 13
#
# Batch 111
# Batch correct = 14
#
# Batch 112
# Batch correct = 9
#
# Batch 113
# Batch correct = 13
#
# Batch 114
# Batch correct = 6
#
# Batch 115
# Batch correct = 11
#
# Batch 116
# Batch correct = 6
#
# Batch 117
# Batch correct = 8
#
# Batch 118
# Batch correct = 9
#
# Batch 119
# Batch correct = 8
#
# Batch 120
# Batch correct = 14
#
# Batch 121
# Batch correct = 16
#
# Batch 122
# Batch correct = 16
#
# Batch 123
# Batch correct = 13
#
# Batch 124
# Batch correct = 2
#
# Batch 125
# Batch correct = 2
#
# Batch 126
# Batch correct = 1
#
# Batch 127
# Batch correct = 1
#
# Batch 128
# Batch correct = 5
#
# Batch 129
# Batch correct = 2
#
# Batch 130
# Batch correct = 2
#
# Batch 131
# Batch correct = 2
#
# Batch 132
# Batch correct = 2
#
# Batch 133
# Batch correct = 3
#
# Batch 134
# Batch correct = 1
#
# Batch 135
# Batch correct = 4
#
# Batch 136
# Batch correct = 10
#
# Batch 137
# Batch correct = 1
#
# DONE.
# Total correct =  1214
# Test accuracy = 0.56
#               precision    recall  f1-score   support
#
#            0       0.59      0.61      0.60      1186
#            1       0.51      0.49      0.50       991
#
#     accuracy                           0.56      2177
#    macro avg       0.55      0.55      0.55      2177
# weighted avg       0.56      0.56      0.56      2177
#
# [[725 461]
#  [502 489]]
